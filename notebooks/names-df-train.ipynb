# %%
import tensorflow as tf

import numpy as np
import time

# %%
from names import check, raw_data, vectorize, seq_model
from names.rules_based import census, from_file, npc_gen

# %% [markdown]
# ### Read the data
#
# First, look in the text:

# %%
vocab = check.default_vocab()

# %%
df_census = census.census()
df_census
# Out:
#             name gender  count  year     source
# 0           Mary      F   7065  1880  US census
# 1           Anna      F   2604  1880  US census
# 2           Emma      F   2003  1880  US census
# 3      Elizabeth      F   1939  1880  US census
# 4         Minnie      F   1746  1880  US census
# ...          ...    ...    ...   ...        ...
# 31266     Zykell      M      5  2020  US census
# 31267      Zylus      M      5  2020  US census
# 31268     Zymari      M      5  2020  US census
# 31269        Zyn      M      5  2020  US census
# 31270      Zyran      M      5  2020  US census
#
# [2020863 rows x 5 columns]

# %%
df_jrpg = from_file.jrpg()
df_jrpg
# Out:
#                name      source
# 0     Adray Lasbard  jrpg names
# 1         Albel Nox  jrpg names
# 2      Cliff Fittir  jrpg names
# 3      Fayt Leingod  jrpg names
# 4     Maria Traydor  jrpg names
# ...             ...         ...
# 6450         Zurvan  jrpg names
# 6451           Zuta  jrpg names
# 6452           ZuZu  jrpg names
# 6453           Zyle  jrpg names
# 6454           Zyle  jrpg names
#
# [6455 rows x 2 columns]

# %%
all_dfs = npc_gen.all_dfs()

# %%
all_dfs.append(df_census)
all_dfs.append(df_jrpg)

# %%
raw = []
for _ in range(100):
    raw = raw + raw_data.sample_from_dfs(all_dfs, k=100)

# %%
raw[-20:]
# Out:
# ["{'source': 'jrpg names'}\nRagelise B Baloumat",
#  "{'source': 'jrpg names'}\nMary",
#  "{'source': 'jrpg names'}\nJovan",
#  "{'source': 'jrpg names'}\nGarret",
#  "{'source': 'jrpg names'}\nKulvan's Daughter",
#  "{'source': 'jrpg names'}\nReks",
#  "{'source': 'jrpg names'}\nZorn and Thorn",
#  "{'source': 'jrpg names'}\nBroken Mountain",
#  "{'source': 'jrpg names'}\nNótt",
#  "{'source': 'jrpg names'}\nAsura",
#  "{'source': 'jrpg names'}\nZangan",
#  "{'source': 'jrpg names'}\nMaroda",
#  "{'source': 'jrpg names'}\nKotokaze Benitoki",
#  "{'source': 'jrpg names'}\nVelouria",
#  "{'source': 'jrpg names'}\nBorlov",
#  "{'source': 'jrpg names'}\nFayt Leingod",
#  "{'source': 'jrpg names'}\nTigris",
#  "{'source': 'jrpg names'}\nGrog",
#  "{'source': 'jrpg names'}\nVelibor Azetina",
#  "{'source': 'jrpg names'}\nMaria"]

# %%
text = raw_data.join_raw(raw)

# %%
text[:300]
# Out:
# "{'gender': 'F', 'source': 'npc female dwarf'}\nThraa                                                 \n{'gender': 'F', 'source': 'npc female dwarf'}\nEbloda                                                \n{'gender': 'F', 'source': 'npc female dwarf'}\nGunnrasa                                            "

# %% [markdown]
# ### The prediction task

# %% [markdown]
# Given a character, or a sequence of characters, what is the most probable next character? This is the task you're training the model to perform. The input to the model will be a sequence of characters, and you train the model to predict the output—the following character at each time step.
#
# Since RNNs maintain an internal state that depends on the previously seen elements, given all the characters computed until this moment, what is the next character?

# %% [markdown]
# ### Create training examples and targets
#
# Next divide the text into example sequences. Each input sequence will contain `seq_length` characters from the text.
#
# For each input sequence, the corresponding targets contain the same length of text, except shifted one character to the right.
#
# So break the text into chunks of `seq_length+1`. For example, say `seq_length` is 4 and our text is "Hello". The input sequence would be "Hell", and the target sequence "ello".
#
# To do this first use the `tf.data.Dataset.from_tensor_slices` function to convert the text vector into a stream of character indices.

# %%
ds = vectorize.DataSet(text, vocab=vocab)

# %% [markdown]
# The `batch` method lets you easily convert these individual characters to sequences of the desired size.

# %% [markdown]
# For training you'll need a dataset of `(input, label)` pairs. Where `input` and
# `label` are sequences. At each time step the input is the current character and the label is the next character.
#
# Here's a function that takes a sequence as input, duplicates, and shifts it to align the input and label for each timestep:

# %%
vectorize.split_input_target(list("Tensorflow"))
# Out:
# (['T', 'e', 'n', 's', 'o', 'r', 'f', 'l', 'o'],
#  ['e', 'n', 's', 'o', 'r', 'f', 'l', 'o', 'w'])

# %% [markdown]
# ### Create training batches
#
# You used `tf.data` to split the text into manageable sequences. But before feeding this data into the model, you need to shuffle the data and pack it into batches.

# %% [markdown]
# ## Build The Model

# %% [markdown]
# This section defines the model as a `keras.Model` subclass (For details see [Making new Layers and Models via subclassing](https://www.tensorflow.org/guide/keras/custom_layers_and_models)).
#
# This model has three layers:
#
# * `tf.keras.layers.Embedding`: The input layer. A trainable lookup table that will map each character-ID to a vector with `embedding_dim` dimensions;
# * `tf.keras.layers.GRU`: A type of RNN with size `units=rnn_units` (You can also use an LSTM layer here.)
# * `tf.keras.layers.Dense`: The output layer, with `vocab_size` outputs. It outputs one logit for each character in the vocabulary. These are the log-likelihood of each character according to the model.

# %%
# Length of the vocabulary in chars
# vocab_size = len(vocab)

# The embedding dimension
embedding_dim = 256

# Number of RNN units
rnn_units = [1024, 1024]

# %%
model = seq_model.SeqModel(vocab,
        embedding_dim=embedding_dim,
        rnn_units=rnn_units)

# %% [markdown]
# For each character the model looks up the embedding, runs the GRU one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-likelihood of the next character:
#
# ![A drawing of the data passing through the model](images/text_generation_training.png)

# %% [markdown]
# Note: For training you could use a `keras.Sequential` model here. To  generate text later you'll need to manage the RNN's internal state. It's simpler to include the state input and output options upfront, than it is to rearrange the model architecture later. For more details see the [Keras RNN guide](https://www.tensorflow.org/guide/keras/rnn#rnn_state_reuse).

# %% [markdown]
# ## Try the model
#
# Now run the model to see that it behaves as expected.
#
# First check the shape of the output:

# %%
for input_example_batch, target_example_batch in ds.dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")
# Out:
# (64, 100, 179) # (batch_size, sequence_length, vocab_size)

# %% [markdown]
# In the above example the sequence length of the input is `100` but the model can be run on inputs of any length:

# %%
model.summary()
# Out:
# Model: "seq_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  45824
# _________________________________________________________________
# gru (GRU)                    multiple                  3938304
# _________________________________________________________________
# gru_1 (GRU)                  multiple                  6297600
# _________________________________________________________________
# dense (Dense)                multiple                  183475
# =================================================================
# Total params: 10,465,203
# Trainable params: 10,465,203
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# To get actual predictions from the model you need to sample from the output distribution, to get actual character indices. This distribution is defined by the logits over the character vocabulary.
#
# Note: It is important to _sample_ from this distribution as taking the _argmax_ of the distribution can easily get the model stuck in a loop.
#
# Try it for the first example in the batch:

# %%
sampled_indices = tf.random.categorical(example_batch_predictions[0], num_samples=1)
sampled_indices = tf.squeeze(sampled_indices, axis=-1).numpy()

# %% [markdown]
# This gives us, at each timestep, a prediction of the next character index:

# %%
sampled_indices
# Out:
# array([ 24, 146,  50, 153, 154,  20, 161,  16,  79, 157, 104, 104,  30,
#         58, 146,  60, 174,  41,  42,  32,  64,  42,   0,  54,  96, 143,
#         80,  41, 112, 151,  97,   8, 127,  91, 109,   2, 174, 171,  65,
#        160,  62,  22, 131,  41, 146,   0,  16,  44,   8,  55,  64,  90,
#        137, 173,  95,  33,  21, 119,  95,  70, 142, 120, 107,  51, 140,
#         85, 162, 157, 118,  58, 151,  76,  33, 132, 167,  79, 112,  69,
#        155,  98,  72,  70, 133,  76, 172,   4,   1, 169,  15,  20,  36,
#        117, 124, 140,  88, 165, 163,  79, 147,  65], dtype=int64)

# %% [markdown]
# Decode these to see the text predicted by this untrained model:

# %%
print("Input:\n", ds.text_from_ids(np.array([input_example_batch[0]])))
print()
print("Next Char Predictions:\n", ds.text_from_ids(np.array([sampled_indices])))
# Out:
# Input:
#  ["{'gender': 'F', 'source': 'npc female human'}\nZhanna                                                "]
#
# Next Char Predictions:
#  ['-γἔ\\"ą,ὰrømmáñγ\t/pίώτί[UNK]ἰyjcpë!íkłùRv/|Â ldàpγ[UNK]ὰak<τπï%υL2Wυu#äε}èU0øSñ!ÕLAαrë]\n\'δuΩÕÓ9$ῦ+ąCÄâèübÖrςÂ']

# %% [markdown]
# ## Train the model

# %% [markdown]
# At this point the problem can be treated as a standard classification problem. Given the previous RNN state, and the input this time step, predict the class of the next character.

# %% [markdown]
# ### Attach an optimizer, and a loss function

# %% [markdown]
# The standard `tf.keras.losses.sparse_categorical_crossentropy` loss function works in this case because it is applied across the last dimension of the predictions.
#
# Because your model returns logits, you need to set the `from_logits` flag.

# %%
example_batch_loss = model.loss(target_example_batch, example_batch_predictions)
mean_loss = example_batch_loss.numpy().mean()
print("Prediction shape: ", example_batch_predictions.shape, " # (batch_size, sequence_length, vocab_size)")
print("Mean loss:        ", mean_loss)
# Out:
# Prediction shape:  (64, 100, 179)  # (batch_size, sequence_length, vocab_size)
# Mean loss:         5.1878495

# %% [markdown]
# A newly initialized model shouldn't be too sure of itself, the output logits should all have similar magnitudes. To confirm this you can check that the exponential of the mean loss is approximately equal to the vocabulary size. A much higher loss means the model is sure of its wrong answers, and is badly initialized:

# %%
tf.exp(mean_loss).numpy()
# Out:
# 179.08302

# %% [markdown]
# Configure the training procedure using the `tf.keras.Model.compile` method. Use `tf.keras.optimizers.Adam` with default arguments and the loss function.

# %%
model.compile_model()

# %% [markdown]
# ### Configure checkpoints

# %% [markdown]
# Use a `tf.keras.callbacks.ModelCheckpoint` to ensure that checkpoints are saved during training:

# %%
chk = check.CheckPoint("all_df_model")

# %% [markdown]
# ### Execute the training

# %% [markdown]
# To keep training time reasonable, use 10 epochs to train the model. In Colab, set the runtime to GPU for faster training.

# %%
EPOCHS = 20

# %%
history = model.fit_with_chk(ds, checkpoint=chk, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 1365/1365 [==============================] - 125s 89ms/step - loss: 0.3211
# Epoch 2/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1727
# Epoch 3/20
# 1365/1365 [==============================] - 127s 93ms/step - loss: 0.1549
# Epoch 4/20
# 1365/1365 [==============================] - 127s 92ms/step - loss: 0.1401
# Epoch 5/20
# 1365/1365 [==============================] - 127s 92ms/step - loss: 0.1320
# Epoch 6/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1266
# Epoch 7/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1228
# Epoch 8/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1190
# Epoch 9/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1159
# Epoch 10/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1151
# Epoch 11/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1149
# Epoch 12/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1115
# Epoch 13/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1120
# Epoch 14/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1109
# Epoch 15/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1103
# Epoch 16/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1098
# Epoch 17/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1120
# Epoch 18/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1099
# Epoch 19/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1137
# Epoch 20/20
# 1365/1365 [==============================] - 126s 92ms/step - loss: 0.1072

# %%
one_step_model = seq_model.OneStep(model)

# %%
chk.save(model)

# %%
def generate_names(stem="", n=1):
    names = []
    for _ in range(n):
        states = None
        next_char = [stem + ch for ch in "QWERTYUIOPASDFGHJKLZXCVBNM"]
        next_char = tf.constant(next_char)
        result = [next_char]

        for n in range(40):
          next_char, states = one_step_model.generate_one_step(next_char, states=states)
          result.append(next_char)

        result = tf.strings.join(result)
        names += [" ".join([a.strip() for a in name.decode("utf-8").split() if len(a)]) for name in result.numpy()]
    return names

# %%
generate_names(stem="{'source': 'jrpg names'}\n", n=10)
# Out:
# ["{'source': 'jrpg names'} Queen Seline",
#  "{'source': 'jrpg names'} Waimemant Soribo",
#  "{'source': 'jrpg names'} Elifa",
#  "{'source': 'jrpg names'} Rowmen",
#  "{'source': 'jrpg names'} T'yanch",
#  "{'source': 'jrpg names'} Yue",
#  "{'source': 'jrpg names'} Ulark",
#  "{'source': 'jrpg names'} Ingus",
#  "{'source': 'jrpg names'} Olvara",
#  "{'source': 'jrpg names'} Pryna",
#  "{'source': 'jrpg names'} Athello",
#  "{'source': 'jrpg names'} Shoga",
#  "{'source': 'jrpg names'} Duke Vox",
#  "{'source': 'jrpg names'} Fidel Camuze",
#  "{'source': 'jrpg names'} Garill",
#  "{'source': 'jrpg names'} Hob",
#  "{'source': 'jrpg names'} Jantellot de Thelomaire",
#  "{'source': 'jrpg names'} Kevin Bachtein",
#  "{'source': 'jrpg names'} Loot",
#  "{'source': 'jrpg names'} Zophiel",
#  "{'source': 'jrpg names'} X'rhhun Tiint",
#  "{'source': 'jrpg names'} Cidouse",
#  "{'source': 'jrpg names'} Vayne's Reurstinel",
#  "{'source': 'jrpg names'} Bias",
#  "{'source': 'jrpg names'} Nyle",
#  "{'source': 'jrpg names'} Maroda",
#  "{'source': 'jrpg names'} Quan",
#  "{'source': 'jrpg names'} Wrys",
#  "{'source': 'jrpg names'} Eald'",
#  "{'source': 'jrpg names'} Rogier",
#  "{'source': 'jrpg names'} Talan",
#  "{'source': 'jrpg names'} Yves",
#  "{'source': 'jrpg names'} Urhil",
#  "{'source': 'jrpg names'} Insuper",
#  "{'source': 'jrpg names'} Octo",
#  "{'source': 'jrpg names'} Pavine",
#  "{'source': 'jrpg names'} Akh Sako",
#  "{'source': 'jrpg names'} Shai Modita",
#  "{'source': 'jrpg names'} Dhagon",
#  "{'source': 'jrpg names'} Fairy of Winds",
#  "{'source': 'jrpg names'} Gloucester",
#  "{'source': 'jrpg names'} Hilda",
#  "{'source': 'jrpg names'} Jeweller",
#  "{'source': 'jrpg names'} Kilton",
#  "{'source': 'jrpg names'} Lewena",
#  "{'source': 'jrpg names'} Zavhil",
#  "{'source': 'jrpg names'} X'rhun Kairs",
#  "{'source': 'jrpg names'} Chaas Qecae",
#  "{'source': 'jrpg names'} Vidofnir",
#  "{'source': 'jrpg names'} Bosco",
#  "{'source': 'jrpg names'} Nolanel",
#  "{'source': 'jrpg names'} Mayor Allend",
#  "{'source': 'jrpg names'} Queeq Snerrik",
#  "{'source': 'jrpg names'} Wandigo",
#  "{'source': 'jrpg names'} Ellie Ryse",
#  "{'source': 'jrpg names'} Roplee",
#  "{'source': 'jrpg names'} Tangor Alle",
#  "{'source': 'jrpg names'} Yugiri Mistwalker",
#  "{'source': 'jrpg names'} Unnarack",
#  "{'source': 'jrpg names'} Ivan",
#  "{'source': 'jrpg names'} Olivoi",
#  "{'source': 'jrpg names'} Phanna",
#  "{'source': 'jrpg names'} Ajido-Marujido",
#  "{'source': 'jrpg names'} Surleno",
#  "{'source': 'jrpg names'} Dejona",
#  "{'source': 'jrpg names'} Fishn",
#  "{'source': 'jrpg names'} Guy",
#  "{'source': 'jrpg names'} Hiar Hattree",
#  "{'source': 'jrpg names'} Joshuaroch",
#  "{'source': 'jrpg names'} Kumop",
#  "{'source': 'jrpg names'} Lobas",
#  "{'source': 'jrpg names'} Zubora",
#  "{'source': 'jrpg names'} X'rry",
#  "{'source': 'jrpg names'} Cindy Aurum",
#  "{'source': 'jrpg names'} Vendor",
#  "{'source': 'jrpg names'} Barstaur",
#  "{'source': 'jrpg names'} Nieh van Garlsbornc",
#  "{'source': 'jrpg names'} Madame Merkhan",
#  "{'source': 'jrpg names'} Queen Stelle",
#  "{'source': 'jrpg names'} Weator",
#  "{'source': 'jrpg names'} Eleanor",
#  "{'source': 'jrpg names'} Rosa's mother",
#  "{'source': 'jrpg names'} Tist-Lenna",
#  "{'source': 'jrpg names'} Yuichi Oakville",
#  "{'source': 'jrpg names'} Ulrich",
#  "{'source': 'jrpg names'} Ioshun Shield",
#  "{'source': 'jrpg names'} Olivarro",
#  "{'source': 'jrpg names'} Pamela",
#  "{'source': 'jrpg names'} Aire-Houl",
#  "{'source': 'jrpg names'} Shar Zeldo",
#  "{'source': 'jrpg names'} Derek Karst",
#  "{'source': 'jrpg names'} Fumuepou",
#  "{'source': 'jrpg names'} Gabranth",
#  "{'source': 'jrpg names'} Hauker",
#  "{'source': 'jrpg names'} Jakob",
#  "{'source': 'jrpg names'} King of Heartil",
#  "{'source': 'jrpg names'} Lilith",
#  "{'source': 'jrpg names'} Zhaleq",
#  "{'source': 'jrpg names'} Xevinec I",
#  "{'source': 'jrpg names'} Carbuncle",
#  "{'source': 'jrpg names'} Vampru",
#  "{'source': 'jrpg names'} Blair Lansfeld",
#  "{'source': 'jrpg names'} Nobolo",
#  "{'source': 'jrpg names'} Machyul",
#  "{'source': 'jrpg names'} Qukato Nah",
#  "{'source': 'jrpg names'} Whyt",
#  "{'source': 'jrpg names'} Emma",
#  "{'source': 'jrpg names'} Rosa-Soruki",
#  "{'source': 'jrpg names'} Tibarn",
#  "{'source': 'jrpg names'} Yabaron",
#  "{'source': 'jrpg names'} Ulikra",
#  "{'source': 'jrpg names'} Ismaire",
#  "{'source': 'jrpg names'} Orenda",
#  "{'source': 'jrpg names'} Porom",
#  "{'source': 'jrpg names'} Aera Mirus Fleuret/eir",
#  "{'source': 'jrpg names'} Saiolai",
#  "{'source': 'jrpg names'} Dajh Katzroy",
#  "{'source': 'jrpg names'} F'lhamind Qesh",
#  "{'source': 'jrpg names'} Gosea",
#  "{'source': 'jrpg names'} Horg",
#  "{'source': 'jrpg names'} Jesle",
#  "{'source': 'jrpg names'} Kreeb",
#  "{'source': 'jrpg names'} Leon",
#  "{'source': 'jrpg names'} Zenos zas Shop",
#  "{'source': 'jrpg names'} Xaila",
#  "{'source': 'jrpg names'} Chao",
#  "{'source': 'jrpg names'} Vivi Ornitier",
#  "{'source': 'jrpg names'} Beyard",
#  "{'source': 'jrpg names'} Nero family",
#  "{'source': 'jrpg names'} Maria Tray",
#  "{'source': 'jrpg names'} Qishil",
#  "{'source': 'jrpg names'} Welch Vineyard",
#  "{'source': 'jrpg names'} Emma",
#  "{'source': 'jrpg names'} Ragrie",
#  "{'source': 'jrpg names'} Travant",
#  "{'source': 'jrpg names'} Yang",
#  "{'source': 'jrpg names'} Ulnibal",
#  "{'source': 'jrpg names'} Ielach",
#  "{'source': 'jrpg names'} Oe Dalace",
#  "{'source': 'jrpg names'} Palmer",
#  "{'source': 'jrpg names'} Ashoron",
#  "{'source': 'jrpg names'} ShadyMo",
#  "{'source': 'jrpg names'} Diardin",
#  "{'source': 'jrpg names'} Fofli",
#  "{'source': 'jrpg names'} Giffo",
#  "{'source': 'jrpg names'} Hinox",
#  "{'source': 'jrpg names'} Johnny",
#  "{'source': 'jrpg names'} Klaus Bachtein",
#  "{'source': 'jrpg names'} Lian",
#  "{'source': 'jrpg names'} Zangan",
#  "{'source': 'jrpg names'} X'rhun Tia",
#  "{'source': 'jrpg names'} Crepera Lucis Caelum",
#  "{'source': 'jrpg names'} Valoo",
#  "{'source': 'jrpg names'} Baldwukk",
#  "{'source': 'jrpg names'} Nogeloix",
#  "{'source': 'jrpg names'} Mayur",
#  "{'source': 'jrpg names'} Queen Seline",
#  "{'source': 'jrpg names'} Wodd",
#  "{'source': 'jrpg names'} Epongu",
#  "{'source': 'jrpg names'} Ridley Silverlake",
#  "{'source': 'jrpg names'} Tina",
#  "{'source': 'jrpg names'} Yaag Noh",
#  "{'source': 'jrpg names'} Ulir",
#  "{'source': 'jrpg names'} Ingrod",
#  "{'source': 'jrpg names'} Olvara",
#  "{'source': 'jrpg names'} P'yandih",
#  "{'source': 'jrpg names'} Agrsam",
#  "{'source': 'jrpg names'} Shantotto",
#  "{'source': 'jrpg names'} Dedra",
#  "{'source': 'jrpg names'} Febail",
#  "{'source': 'jrpg names'} Ghastar",
#  "{'source': 'jrpg names'} Hint",
#  "{'source': 'jrpg names'} Jake",
#  "{'source': 'jrpg names'} Kulvan's D-Obalatnie",
#  "{'source': 'jrpg names'} Lespava",
#  "{'source': 'jrpg names'} Zhara",
#  "{'source': 'jrpg names'} Xeven Svanseva",
#  "{'source': 'jrpg names'} Chloe",
#  "{'source': 'jrpg names'} Vauthry",
#  "{'source': 'jrpg names'} Brendan",
#  "{'source': 'jrpg names'} Nogenix",
#  "{'source': 'jrpg names'} Maat",
#  "{'source': 'jrpg names'} Qoqoba",
#  "{'source': 'jrpg names'} Wian",
#  "{'source': 'jrpg names'} Eldance",
#  "{'source': 'jrpg names'} Rowan",
#  "{'source': 'jrpg names'} Tadric",
#  "{'source': 'jrpg names'} Yves",
#  "{'source': 'jrpg names'} Ulrich",
#  "{'source': 'jrpg names'} Iuchar",
#  "{'source': 'jrpg names'} Old Hentin",
#  "{'source': 'jrpg names'} Pumm",
#  "{'source': 'jrpg names'} A-Towa-Cant",
#  "{'source': 'jrpg names'} Sheik",
#  "{'source': 'jrpg names'} Dekk Farrick",
#  "{'source': 'jrpg names'} Fard Eagle",
#  "{'source': 'jrpg names'} Guy",
#  "{'source': 'jrpg names'} Hewerald",
#  "{'source': 'jrpg names'} Jo go",
#  "{'source': 'jrpg names'} Kiah Cora",
#  "{'source': 'jrpg names'} Layle",
#  "{'source': 'jrpg names'} Zephirin Valeth",
#  "{'source': 'jrpg names'} Xev Ocher",
#  "{'source': 'jrpg names'} Chio",
#  "{'source': 'jrpg names'} Vendor",
#  "{'source': 'jrpg names'} Brandan",
#  "{'source': 'jrpg names'} Nida",
#  "{'source': 'jrpg names'} Mogg",
#  "{'source': 'jrpg names'} Quan",
#  "{'source': 'jrpg names'} Waldens",
#  "{'source': 'jrpg names'} Evil Eagle",
#  "{'source': 'jrpg names'} Ruddle Crispin",
#  "{'source': 'jrpg names'} Tona",
#  "{'source': 'jrpg names'} Yoshi Mah",
#  "{'source': 'jrpg names'} Umbra",
#  "{'source': 'jrpg names'} Island Chief",
#  "{'source': 'jrpg names'} Opera Vectra",
#  "{'source': 'jrpg names'} Pehainel",
#  "{'source': 'jrpg names'} Alora",
#  "{'source': 'jrpg names'} Sho",
#  "{'source': 'jrpg names'} Deumion",
#  "{'source': 'jrpg names'} Fausterach",
#  "{'source': 'jrpg names'} Gerolt",
#  "{'source': 'jrpg names'} Harl",
#  "{'source': 'jrpg names'} Joel",
#  "{'source': 'jrpg names'} Knlyn",
#  "{'source': 'jrpg names'} Lady Maud",
#  "{'source': 'jrpg names'} Zeppre",
#  "{'source': 'jrpg names'} X'rhon Naddur amacrele",
#  "{'source': 'jrpg names'} Corn Boy",
#  "{'source': 'jrpg names'} Verda Tuel",
#  "{'source': 'jrpg names'} Brignend of Brotherdieldes ans",
#  "{'source': 'jrpg names'} Nasir",
#  "{'source': 'jrpg names'} MrdaechCo",
#  "{'source': 'jrpg names'} Queen Stella",
#  "{'source': 'jrpg names'} Wilff",
#  "{'source': 'jrpg names'} Estle Mater",
#  "{'source': 'jrpg names'} Ruddle Crispin",
#  "{'source': 'jrpg names'} Tasedae",
#  "{'source': 'jrpg names'} Yas Meggamuice",
#  "{'source': 'jrpg names'} Ulkiy",
#  "{'source': 'jrpg names'} Iranderick",
#  "{'source': 'jrpg names'} Owron",
#  "{'source': 'jrpg names'} Pavine",
#  "{'source': 'jrpg names'} Alut",
#  "{'source': 'jrpg names'} Shad",
#  "{'source': 'jrpg names'} Dorney",
#  "{'source': 'jrpg names'} Fishman",
#  "{'source': 'jrpg names'} Gunter",
#  "{'source': 'jrpg names'} Hinox",
#  "{'source': 'jrpg names'} Joonich",
#  "{'source': 'jrpg names'} Kokkol",
#  "{'source': 'jrpg names'} Luwis",
#  "{'source': 'jrpg names'} Zageth",
#  "{'source': 'jrpg names'} X'rhochia",
#  "{'source': 'jrpg names'} Cameron",
#  "{'source': 'jrpg names'} Vandefol",
#  "{'source': 'jrpg names'} Bertri",
#  "{'source': 'jrpg names'} Nataldiur",
#  "{'source': 'jrpg names'} Mackwell"]

# %%
generate_names("{'gender': 'F', 'source': 'npc female dwarf'}\n")
# Out:
# ["{'gender': 'F', 'source': 'npc female dwarf'} Quari",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Wharla",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Ebloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Rurnal",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Toris",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Yuris",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Ulfis",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Iil",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Ohild",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Palnal",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Audloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Soril",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Dkil",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Filif",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Golloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Hlla",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Jilloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Konhild",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Liftis",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Zulla",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Xolloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Colla",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Valil",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Brottrasa",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Noloda",
#  "{'gender': 'F', 'source': 'npc female dwarf'} Morhild"]

# %%
generate_names("{'gender': 'M', 'source': 'npc male dwarf'}\n")
# Out:
# ["{'gender': 'M', 'source': 'npc male dwarf'} Queen",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Wharik",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Ebik",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Rurur",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Thraik",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Yurur",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Ulfar",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Iblud",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Obon",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Polin",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Artbon",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Sonic",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Dwalerk",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Filic",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Gunnto",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Hlerk",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Jilik",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Korlinn",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Liftkil",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Zurkil",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Xalik",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Collum",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Vlottlum",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Brottor",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Norar",
#  "{'gender': 'M', 'source': 'npc male dwarf'} Morbon"]

# %%
generate_names("{'source': 'jrpg names'}\nJoby the ")
# Out:
# ["{'source': 'jrpg names'} Joby the Quore",
#  "{'source': 'jrpg names'} Joby the Wale",
#  "{'source': 'jrpg names'} Joby the Eston",
#  "{'source': 'jrpg names'} Joby the Rogan",
#  "{'source': 'jrpg names'} Joby the Thomen of Stwille",
#  "{'source': 'jrpg names'} Joby the Youngeles",
#  "{'source': 'jrpg names'} Joby the Ulgid",
#  "{'source': 'jrpg names'} Joby the Indolstak",
#  "{'source': 'jrpg names'} Joby the Ornorie",
#  "{'source': 'jrpg names'} Joby the Proekser",
#  "{'source': 'jrpg names'} Joby the Armainbeldt",
#  "{'source': 'jrpg names'} Joby the Shonnel",
#  "{'source': 'jrpg names'} Joby the Delmatte",
#  "{'source': 'jrpg names'} Joby the Forney",
#  "{'source': 'jrpg names'} Joby the Gunters",
#  "{'source': 'jrpg names'} Joby the Hext",
#  "{'source': 'jrpg names'} Joby the Jatore",
#  "{'source': 'jrpg names'} Joby the Kentoo",
#  "{'source': 'jrpg names'} Joby the Lohe",
#  "{'source': 'jrpg names'} Joby the Zeola",
#  "{'source': 'jrpg names'} Joby the XInano",
#  "{'source': 'jrpg names'} Joby the Colelace",
#  "{'source': 'jrpg names'} Joby the Valeron",
#  "{'source': 'jrpg names'} Joby the Booulsorous",
#  "{'source': 'jrpg names'} Joby the Noh",
#  "{'source': 'jrpg names'} Joby the Mon Falouire"]

# %%
generate_names(stem="{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'}\n")
# Out:
# ["{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Quinn",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Wedelyne",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Estee st",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Roxana vi",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Themeca",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Yodel",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Ulgie",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Irene ly",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Oyachume e",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Peyton chi",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Anna",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Sonna",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Dila is",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Franceich l",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Guldo",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Hanne ri",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Josette le",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Kita",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Lochee ch",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Zanea",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Xena ar",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Catherine um",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Viece",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Barde",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Noo",
#  "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'} Matta"]

# %%
generate_names(stem="{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'}\n")
# Out:
# ["{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Queen ie",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Weston e",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Eller es",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Rollie",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Tiey",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Yabor",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Ulis",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Ilee",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Odell",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Philope",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Avontae",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Sullivan",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Delliot e",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Fidnell c",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Gens es",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Hassie",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Jessley es",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Komai",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Lady",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Zak",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Xelia",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Clyya",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Vernell",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Ballard fe",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Nevval",
#  "{'gender': 'M', 'count': 10, 'year': 1880, 'source': 'US census'} Morrie"]

# %%
raw_data.row2sample(df_census.iloc[0])
# Out:
# "{'gender': 'F', 'count': 7065, 'year': 1880, 'source': 'US census'}\nMary"

# %%
place = []
for name in generate_names():
    name = name.split()[0]
    for long_name in generate_names(name + " of "):
        print(long_name)
        place.append(long_name.split()[2])
# Out:
# QuLShark of Qegre wah
# QuLShark of Warns ish
# QuLShark of Els
# QuLShark of Raly
# QuLShark of Thalmarc
# QuLShark of Ya us
# QuLShark of UShancant is a enthis
# QuLShark of I wit
# QuLShark of Oman
# QuLShark of Palhandem: ':mances': 'sour':': 's urce':
# QuLShark of Ald Mat
# QuLShark of Shaminder': 'sour': ': 'sour': ': 'r'ur':
# QuLShark of DallsPi:t's'8an': ': 'sour': ': cen'ur':'
# QuLShark of Farcha vil
# QuLShark of Galvi
# QuLShark of Hl0:
# QuLShark of Jalla-PKfidras is
# QuLShark of Kanna
# QuLShark of Laphari: vin
# QuLShark of Zalmas
# QuLShark of Xa el
# QuLShark of Car': sied
# QuLShark of Vall us ': as uce':
# QuLShark of Bardi:
# QuLShark of Nan is
# QuLShark of Mangel chi
# WhwSitha of QiXS1mannus': 'soune': 'US census'} Satar
# WhwSitha of Wim: 'source': 's urce': 'US census'} Mar
# WhwSitha of Ensemar': 'source': 'source': 'source': '
# WhwSitha of Rikb: 5sour ': ': 'sourc:': ': gnor': 'F'
# WhwSitha of T'anger': 's ur': 's urce': 's'S 'sus'} O
# WhwSitha of Ysevi: ': 'sour': ': 's urce': 'US census
# WhwSitha of UMmar':r':': 'source': 'US censuu'} Dwagn
# WhwSitha of Ince's ':r'suur': 'source': 's urce': 'US
# WhwSitha of Onder': er': 's'urce': 'Us census'} Davyn
# WhwSitha of Peur': 'sourc': 'source': ':rce':': 'sour
# WhwSitha of Asrckar': 'source': 's'urce': 'source': '
# WhwSitha of Sman': esu':': 'source': 'US census'} Dur
# WhwSitha of Dami: eve
# WhwSitha of Fleuer': ur': 'sour': ': 'epes'er':ong':
# WhwSitha of Girr': ': 'suur': 'US 'suurce': 'US censu
# WhwSitha of HlJumi: e ust': use': 'Smarces'} Renn
# WhwSitha of Jenstria ': 'suur': ': census'} Jess
# WhwSitha of Keles': nar': 'source': 'US census'} Dara
# WhwSitha of LX0119: 'source': 'US census'} Donnic
# WhwSitha of Zerker': 'source': 'US census'} Mattavio
# WhwSitha of XS census'} Scertwust': 8s urce': 'rcue':
# WhwSitha of Crancust':rus ': censumus'} Dyen
# WhwSitha of Valinus ': 'sour': ': census'} Ack
# WhwSitha of Berm:l: 's'urce': 'US census'} Watrin
# WhwSitha of Neur': ':ondu:r': 'F'urge': 'US census'}
# WhwSitha of Mi:ces': ': 'source': 's urce': 'US censu
# E-hSoranna of Quimi
# E-hSoranna of Wis
# E-hSoranna of Elko
# E-hSoranna of Ruum
# E-hSoranna of T an
# E-hSoranna of Yus
# E-hSoranna of UMoni: t'suur': ': 'source': ': an': 'n'a
# E-hSoranna of I
# E-hSoranna of O
# E-hSoranna of Pans ch
# E-hSoranna of As':
# E-hSoranna of S la
# E-hSoranna of Daugh
# E-hSoranna of Finlang
# E-hSoranna of Ganleug
# E-hSoranna of Hiand well
# E-hSoranna of Jiald
# E-hSoranna of KVimans
# E-hSoranna of Luuf 'nond': ':on ie
# E-hSoranna of Zumin en
# E-hSoranna of XIV
# E-hSoranna of Cher
# E-hSoranna of Valluus wiek
# E-hSoranna of Bunthernur': 'sour': 's us ': 'source': '
# E-hSoranna of Nana
# E-hSoranna of Mansuma
# Ruurcis of Qe11 werdia
# Ruurcis of Wal:
# Ruurcis of Est': ': non ': 'source': 'US census'} Ma
# Ruurcis of R
# Ruurcis of T wi:t'sur': ':'ysur': 'sourc:': 'npc mal
# Ruurcis of Yang wibana
# Ruurcis of U:moroce': ':oce':': 'source': 'npc 'sour
# Ruurcis of I
# Ruurcis of O'snce': ': 'source': ': censu'': 'source
# Ruurcis of Pi:t'sor': ': ': ':sur': 'source': 'wS ce
# Ruurcis of Asker': ':ker': 'nonet': censuur':': 'sou
# Ruurcis of S9:e'sourc': 'Urkkan's urce': 'US census'
# Ruurcis of Dahumi: ': 2ar': 'nrunt': 7s9S 'suur': 'U
# Ruurcis of Fyns Uponene8: ':one': 'nkur': 'Mount': 6
# Ruurcis of Giand is ander': 'source': 'source': 's'u
# Ruurcis of Hes': 'source': ': c 'source': 'nrce': 'U
# Ruurcis of Jennsus ': 'source': 'j21, 'source': 'US
# Ruurcis of Krans
# Ruurcis of Ligns': 'source': ':oce': 'U: gender': 'U
# Ruurcis of ZhInna
# Ruurcis of XI 'sour': ': ': 'nor ': 'l 2, 'source':
# Ruurcis of Carnis ': 'Mones': 'source': 'j13urce': '
# Ruurcis of Vellous': 'nour': ': ust': 1xones'} Debou
# Ruurcis of Bome hU88J met'er': 'sourr':': 's urce':
# Ruurcis of Nann ward
# Ruurcis of Mesas'Fer': nande ': 'Fs'ur0: 'US 'source
# T'.S89suer': of QuMorges'} Zriria
# T'.S89suer': of We8r': 'npc male eld'} Lian
# T'.S89suer': of Enear': 1956, 'source': 'US census'} Derr
# T'.S89suer': of Ruurce': 'US census'} Arcald
# T'.S89suer': of T arce': 'F', 'source': 'npc male dwarf'}
# T'.S89suer': of Yr': ': unce': 'npc 'ame '} Anto
# T'.S89suer': of U: c namen': 1sur': 1908, 'source': 'US c
# T'.S89suer': of Ir'n': 'nour': 'n'c 'nour': 'npc male hum
# T'.S89suer': of O'g 'n 19g 'npc male elf'} Laucilian
# T'.S89suer': of Pr'a ': cen': gnorc': 's F aria
# T'.S89suer': of Ar': 'npc male el''} Finto
# T'.S89suer': of Soce': 'F', 'source': 'npc male elf'} Ara
# T'.S89suer': of D:pendar': 18: Cara's ander : ': 'sour':
# T'.S89suer': of Fe'r': 'noce': 'F', 'source': 'npc male e
# T'.S89suer': of Gronan':': 'source': 's'cmare
# T'.S89suer': of He': 'npc uame ': 2000y 's Cale
# T'.S89suer': of J 9uras': 1 wiss
# T'.S89suer': of Knorcen: 8:r': census'} Llesue
# T'.S89suer': of L: 19: 'npc emon': 1984, 'source': 'US ce
# T'.S89suer': of Z Lintansas'andar': 'nour': 'US census'}
# T'.S89suer': of X: 8man': 1979, 'source': 'US census'} Ph
# T'.S89suer': of Cruran': 'n9: 'sturce': 'F', 'source': 'n
# T'.S89suer': of V01us': 'source': 'US census'} Darting
# T'.S89suer': of Bruut ': cens'} Garil
# T'.S89suer': of Nece': 'r'c 'n': 'nogr': 19c 'npinan': in
# T'.S89suer': of Mr':': 'noce': 'n5c 'nogr': '901, 'yrar':
# Y'gender': of Quuur'} Friss
# Y'gender': of W'M', 'source': 'npc male human'} Guthum
# Y'gender': of Es'uounce' '9 31 t'year': 2005, 'source'
# Y'gender': of Ruurc': 'spustelesial
# Y'gender': of T'F'sonnus': 'e werd
# Y'gender': of Y'source': 'jrpg names'} Norton
# Y'gender': of UF', 'source': 'npc female dwarf'} Noi
# Y'gender': of I'source': 'F', 'source': 'npc female elf
# Y'gender': of O'c'n 2002, 'source': 'US census'} Maximi
# Y'gender': of Pur': 'npc male elf'} Tharivil
# Y'gender': of Alir': 'npc 'source': 'US census'} Micale
# Y'gender': of S'M', 'source': 'npc male dwarf'} Bombar
# Y'gender': of DM', 'source': 'npc male dwarf'} Kurur
# Y'gender': of F', 'source': 'npc male elf'} Tharilil
# Y'gender': of GFring'} Garret
# Y'gender': of Her': 'M', 'source': 'npc male dwarf'} Bo
# Y'gender': of JF ander':
# Y'gender': of Kernnu': 'F', 'source': 'npc female dwarf
# Y'gender': of LM', 'source': 'npc male elf'} Laucior
# Y'gender': of Z 9ienda ve
# Y'gender': of XM 200unt': 86, 'year': 1987, 'source': '
# Y'gender': of Cor'e': 'M', 'source': 'npc male human'}
# Y'gender': of V01 9source': 'US census'} Anastasia
# Y'gender': of Burpe': 'n census'} Garee
# Y'gender': of N'urce': 'F', 'source': 'npc female elf'}
# Y'gender': of M'source': 'npc male elf'} Helon
# U: of Qu4emen'e'} Denn
# U: of W'source': 'US census'} Daboisha
# U: of E 'eliner': 'M'c 'nt'e clinis Duma
# U: of R us'} Davio
# U: of T'ist's'8st'ian ende
# U: of Yn'r': 'n'c 'n'c male dwarf'} Dar
# U: of Ur 'n'e 's Vildis
# U: of I'gndender': 'n's ildin
# U: of O'gnnnus'} ismo
# U: of Pnnnus'} Dishon
# U: of Ander': 'n'c 'n's 8ntsisha
# U: of S'188 8: cen's'uris e ra
# U: of Dunn': 1981, 'source': 'npc male halfling
# U: of F'c census'} Dommonix
# U: of Gunn': 'noundes': Deman
# U: of Hen'd's imin iscus'} Rossie
# U: of J88s9a eld gels 'st's'ur': 's'trisos'er':
# U: of Knust'} Dominic
# U: of L88s , 'source': 'npc male dwarf'} Bombik
# U: of Z'Doris son
# U: of Xn cens'} Dazeu
# U: of C'ar': elle's'ilis mecie
# U: of V088s uoce': 'npc iale 's Sodia
# U: of Br'n 'nt'88, 'so8me ': census'} Dominic
# U: of N'sour's': cender': 'source': 'npc male d
# U: of Mnnn's'irge hu ', 'source': 'source': 'US
# I'gender': of Q uchier
# I'gender': of W as'sumin
# I'gender': of Es'urce': icktal
# I'gender': of R uathele
# I'gender': of T'urc': 's'Tistan
# I'gender': of Y'source': 'jr census'} Gerold
# I'gender': of Us 1 us': 1meder': 1non': 'M', 'source':
# I'gender': of I'wwum: 'F', 'source': 'epcensus'} Gerge
# I'gender': of O's's Captin
# I'gender': of Puar': 'j27, 'source': 'US census'} Arius
# I'gender': of As's uuscein
# I'gender': of S equil
# I'gender': of Duran': 'M', 'source': 'npc male elf'} La
# I'gender': of F'source': 'jp census'} Devontay
# I'gender': of Gura': 's'uum evel
# I'gender': of Her'F'source': 'jS census'} Rex
# I'gender': of Jenna
# I'gender': of Kuple cc
# I'gender': of Lw978, 'source': 'US census'} Davonta
# I'gender': of Z'S 9ancelle
# I'gender': of XF Asus'} Molth
# I'gender': of C'aris ev
# I'gender': of V iscan
# I'gender': of Bwar': 'F'source': 'jrpg names'} Seeke
# I'gender': of N'sor':': gender': 'M', 'source': 'npc ma
# I'gender': of M'source': 'jrpc names'} Rudolf
# O's/Zeik of Quim uchus
# O's/Zeik of Wans reat
# O's/Zeik of Eliand ur': ': 'w8an': 'US census'} Daunt
# O's/Zeik of Rela welleth
# O's/Zeik of Tiand ur': 'and'ur': 'ale 'uman': umm ':
# O's/Zeik of Y man
# O's/Zeik of Ualm09: '3ane':': 'nua'':': 'sosa':': 'so
# O's/Zeik of I charliun
# O's/Zeik of O
# O's/Zeik of Piant ': 'suusu:': 'souur':': 'US census'
# O's/Zeik of Aln uar': ':'a ': 'source': 'US census'}
# O's/Zeik of S win
# O's/Zeik of Dauma ies
# O's/Zeik of F ia vania
# O's/Zeik of Ga umi
# O's/Zeik of Hii: ': kannua'':': 'e ': 'nt': 'n'u ': '
# O's/Zeik of Ji0le Xanne ': 'suurce': 's'urce': 's ar'
# O's/Zeik of Ka wicha
# O's/Zeik of Lainoc us'c ': e': andan': '5man': 's'grg
# O's/Zeik of Zian ert
# O's/Zeik of XSmathe '0kar': 'suar': 'US census'} Kayt
# O's/Zeik of Car': 'mann: ': 'ntces'} 1hun
# O's/Zeik of Vanla wil
# O's/Zeik of Bamilduan': ': andan': 'susmamemiat'g ur'
# O's/Zeik of Naus wina
# O's/Zeik of Mansuma': ':'u'n ': 'noun': 'US census'}
# Plipg'source': of Qoomis'V Syman
# Plipg'source': of Wonrkel: Fdwama '} Sigar
# Plipg'source': of Er':pevilg'} Simar
# Plipg'source': of Rourt': Sopg'} Soro
# Plipg'source': of Tour': 'US census'} Michola
# Plipg'source': of Yong': 1lS gnos'} Jyon
# Plipg'source': of U: cworcs'US'genas'} Selphie
# Plipg'source': of Ilgngono':'} Anam
# Plipg'source': of O'gr':'} Alia
# Plipg'source': of Pope': 18S cevangnuog'} Filo
# Plipg'source': of As'y ggiaph
# Plipg'source': of Socwmr'} yskor
# Plipg'source': of Dorkel: gnomkia '} Shamman
# Plipg'source': of Fr'apes'} Stryeth
# Plipg'source': of Gorv: Shalile'gng'g eldwimS 'nventhumai}
# Plipg'source': of Hworce': 1lSwcokem: J ophilia
# Plipg'source': of Jous'} Maxantakia
# Plipg'source': of Kong'} Soki
# Plipg'source': of LUS census'} Floritz
# Plipg'source': of Zourker': 'ypele gnome'} Mimota
# Plipg'source': of Xopc uat'} olin
# Plipg'source': of Coros'} Garvatt
# Plipg'source': of Voros'} Mokhil
# Plipg'source': of Borc': 2r1kes'} Shangahn
# Plipg'source': of Noas'} Jim
# Plipg'source': of Mogr':pS orde': 'US census'} Jenya
# And'ur': of Quuumen'} Sammat
# And'ur': of W'alc 'source': 'US census'} Harrell
# And'ur': of Er': 'M', 'source': 'US census'} Emers
# And'ur': of Ruurc': 'n c 's'1um: 'source': 'US census
# And'ur': of T'orce': 'US census'} Jadriel
# And'ur': of Y'urce': 'M', 'source': 'US census'} Layt
# And'ur': of U: 1 '1 'n ce's'} Percil
# And'ur': of I'g'n ce':': 193 ': 1987, 'source': 'US c
# And'ur': of O'' ': 'n'c 's'uuc ': 'lint'gendes'} Mill
# And'ur': of P'','ce's 'umc ch
# And'ur': of Ar': 'M', 'counc': 112, 'year': 1985, 'so
# And'ur': of S'c 'n'c 'n'c 'amc 'npc iame '} 7lia
# And'ur': of DF us'} Duri
# And'ur': of F'gen'e ': '8, 'source': 'US census'} Mar
# And'ur': of Gur': 'US census'} Pranwes
# And'ur': of He'g'} Ruric
# And'ur': of Jer'c ': 1946, 'source': 'US census'} Old
# And'ur': of Kur': 'n'c 'a ': 1951, 'source': 'US cens
# And'ur': of Lo 'n'g 'nog ': 'npe malg dwarf'} Audlinn
# And'ur': of Zuur':': 'n0c 'nmc 'emc 'n cemale 'M', 's
# And'ur': of XF 'ome ': ce's'} Prillie
# And'ur': of Cume': 'npc 'ale dwarf'} Ballum
# And'ur': of Vameli ': 2ame'' 'F 8, 'year': 1954, 'so
# And'ur': of Burce': 'US census'} Shaa
# And'ur': of N'or': 'M', 'source': 'npc male elf'} Tha
# And'ur': of M'c 'nrca': 'n', 'source': 'US census'} R
# S'gge of Quelw29: census'} inkir u
# S'gge of W seander': '9or': 'nrar': 'erce': 1988,
# S'gge of Ege': 'Monene': '09e 'none': '869n er': '
# S'gge of Reuc ': urrc:': t'yr': ce': 'nt'source':
# S'gge of T 9inequume': 'nker': 'nour': 'npc male
# S'gge of Y neve
# S'gge of U89:durces': conder': '8rc'nt'source': '8
# S'gge of I elle
# S'gge of O'g ennia ': cjor'gender': 'jS canes'} Ol
# S'gge of PF9:t'emer': cencond'sousce': 'noce': cem
# S'gge of Arri: ander': 'none': 'source': 'njc oer'
# S'gge of S 91r'gec': 'npas'source': 'US census'} M
# S'gge of DFweisgnurc': ':rcet': xanes': uscine
# S'gge of F innes': ' ur': 'Source': 'nrcr':'c tea
# S'gge of Ganger': 's9urte': 's ur': er': 'er': 'r'
# S'gge of Hexut': nurces': 'source': 'rrc ': 'ntusr
# S'gge of Jer vis
# S'gge of Kanne urcest
# S'gge of L99unnet': fendur': '4ru: ':'urce': 'U9d'
# S'gge of Zewi:': 'sonmce': cencensus'} Matis
# S'gge of XMancathes': 'suar': '9oun:': 'sorrce': '
# S'gge of Car': 'source': 9nma ': 189m, 'cete's'1 1
# S'gge of Vale 'source': '9kemanna 'source': 'ntcen
# S'gge of Br9: 'sonu:e': ':onece': 'US census'} Emm
# S'gge of Ni: 'F 'suurce': 'jS census'} Fabian
# S'gge of Mes': 9source':': 'nource': 'US census'}
# Da-Shira of Quim
# Da-Shira of Wasian
# Da-Shira of Es
# Da-Shira of Rusi: cher
# Da-Shira of T a
# Da-Shira of Ya
# Da-Shira of Usagsor': ': ' ': us': 's'3r':': as's urn
# Da-Shira of I el
# Da-Shira of O
# Da-Shira of Pist umin umen': 1
# Da-Shira of Asal: ie
# Da-Shira of S a
# Da-Shira of Daugelis ichus
# Da-Shira of Farla
# Da-Shira of Gera
# Da-Shira of Hail
# Da-Shira of Jia
# Da-Shira of Karmus
# Da-Shira of Lashale van
# Da-Shira of Zee ip
# Da-Shira of XS
# Da-Shira of Cia
# Da-Shira of Valil
# Da-Shira of Biaf west
# Da-Shira of Naus
# Da-Shira of Malia ther
# F'gender': of Qourmen'} Groar
# F'gender': of Whale 'F'Fuar': 2004, 'source': 'US censu
# F'gender': of Er'g', 'source': 'npc male dwarf'} Hlin
# F'gender': of Rourc': 'F', 'source': 'npc female halfli
# F'gender': of T'irce': '9S 1ensur'} Hart
# F'gender': of Yr'o': 'F', 'source': 'npc female human'}
# F'gender': of UM c 'source': 'npc male gnome'} Dimble
# F'gender': of I'gnunc'} Ruru
# F'gender': of O'gr': 1957, 'source': 'US census'} Edrik
# F'gender': of Por's 'rfesus's'cadir
# F'gender': of Ar': 'M', 'source': 'npc male elf'} Hemol
# F'gender': of S'Monder': 'F', 'source': 'npc female hal
# F'gender': of Dorce': 'F', 'source': 'npc female elf'}
# F'gender': of F'source': 'npc female elf'} Valalanua
# F'gender': of Gorr': 'F', 'source': 'npc female halflin
# F'gender': of Hwarf': 1959, 'source': 'US census'} Hass
# F'gender': of JwS ima
# F'gender': of Konnnor': 'M', 'source': 'npc male dwarf'
# F'gender': of LF 2mor': 'F', 'source': 'npc female half
# F'gender': of Z'Fonna
# F'gender': of XM17, 'year': 1920, 'source': 'US census'
# F'gender': of Coman'e': 'n', 'source': 'US census'} Lay
# F'gender': of V0Ewnny cer
# F'gender': of Bwarf': 2020, 'source': 'US census'} Garn
# F'gender': of N'urce': 'F', 'source': 'npc female elf'}
# F'gender': of M'M 'nt'e 9e '927, 'source': 'US census'}
# Gumcrip'd of Quintras'ut'} Ruheppe
# Gumcrip'd of Wess'} Martust van
# Gumcrip'd of Ester': 'M'ge':':onece': gr'uce': '888, '
# Gumcrip'd of Ronet'yng': 'Mker': 1883t iskc isec Manti
# Gumcrip'd of T'sour': ':pcines': ardin
# Gumcrip'd of Yncine': 'Fonoce': 'Fcceno's': themia
# Gumcrip'd of Ugender': 'UM ce':'Mone': '888b8: 'nt'ye'
# Gumcrip'd of Ingnust': 'ntcer': 'M'ge's', 'source': 'U
# Gumcrip'd of Onger': 'source': 'jj: censuus'} Maximia
# Gumcrip'd of P.onges': Glendisu'rt': 4ar': 'source': '
# Gumcrip'd of Asource': 'F'c 'source': 'UM census'} Dem
# Gumcrip'd of St':r'ec': 4ar': gnor': 'M'ge's': genicke
# Gumcrip'd of Dernander': 'jS4urce': 'US gnor': 'M'g 's
# Gumcrip'd of Fesor': 'gen': 'M'g 'source': 'F', 'sourc
# Gumcrip'd of Genti: ': 1sus'} Minard
# Gumcrip'd of Hender': 'source': 'j88g 's8c 'source': '
# Gumcrip'd of Jeniander': 'nve t': 19t 'rce': 88488, 'y
# Gumcrip'd of Kennender': 'Ur cy': 2omer': 'US 'source'
# Gumcrip'd of Leuge':': 'source': 'source': 'US census'
# Gumcrip'd of Zouce': 'gtce's'ur': 'nour': 'r 'nt'g nnt
# Gumcrip'd of XInter':', 'source': 'US census'} Ventz
# Gumcrip'd of Ciman': er': 'ntcen': c ist's oria
# Gumcrip'd of Vandisu:der': 'U81ge': 2at'yen': 7908, 's
# Gumcrip'd of Beman': 'rkes': 4arn' vi
# Gumcrip'd of Nest':'gnes'eru: 'US census'} Jiammaius
# Gumcrip'd of Mensor': 'source': 'US 'source': 'Ur ce':
# Hedis of Quuer'e ': 1w9r', 'source': 'US census'}
# Hedis of Wele gnust'e 1 119: 2012113an'US census'}
# Hedis of Enel: elg'gender': 'M', 'source': 'npc ma
# Hedis of Resumi: we
# Hedis of T'epen ance
# Hedis of Yusece ie
# Hedis of Us 2ru:e': 1900, 'source': 'npc male elf'
# Hedis of Inders': 'up0 'source': 'jS census'} Mart
# Hedis of Onesus' ' ess
# Hedis of Pemer': ellekelenes'} Zansa
# Hedis of Acker': rees
# Hedis of Sonechum: 'n unt': 115, 'source': 'US cen
# Hedis of Durce': '9912Sosour': 2e3rrk: pancesuur':
# Hedis of Fleonder': 'M', 'source': 'npc male dwarf
# Hedis of Guri: vel
# Hedis of Her': 'source': 'npc male human'} Zhenya
# Hedis of Jume well
# Hedis of Kupin ri
# Hedis of Lelgenus'} Grey
# Hedis of Z ong ec
# Hedis of Xu3a 'e 'n c 's Pell
# Hedis of Ceneri:
# Hedis of Vesenelia ec
# Hedis of Ber': 'noce': 1902, 'source': 'US census'
# Hedis of Nemuma iese
# Hedis of Me's uuce': 'nccet'e c'e gnort'} Lilly
# JK of Quea
# JK of Ward
# JK of Esia
# JK of Risia
# JK of Ta
# JK of Ya
# JK of Ueme
# JK of In
# JK of Oces
# JK of Pamo
# JK of As
# JK of Sil
# JK of De
# JK of Fla
# JK of Gill
# JK of High
# JK of Jinbi
# JK of Ke
# JK of Linn
# JK of Zee
# JK of Xa
# JK of Cine
# JK of Vont
# JK of Barl
# JK of Nais
# JK of Minia
# Killian of Qeer j
# Killian of Walige warth
# Killian of EMle': Gert'ender': 'eonder': 'Fonder': '
# Killian of Rens
# Killian of T e an
# Killian of Yenpuou': ': e 'sorce': 'Um ceneuc'':'gec
# Killian of Uercer':one':': 'sorrce': 'none': 'n'c 's
# Killian of I
# Killian of O welle
# Killian of Peteres': 'soumet': ce':': 'soc'c ': cens
# Killian of Ageen weck
# Killian of S e bert
# Killian of De
# Killian of Fe ': 'anker': 'source': 'r'c 'er': 'r'g
# Killian of Ge e
# Killian of He lynet': ': 'k urr': 'source': '
# Killian of Jells1eant ums ust
# Killian of Kian
# Killian of Leus': ce': 'source': ': cenc'yr':'c 'stu
# Killian of Zeer wellet
# Killian of Xencet'e ce': ':ker': 1quumt emcanec': 1i
# Killian of Come em: nont': cencent'nuce': 'ntcen': g
# Killian of Velltwande ': 'sour': ': 'rrce': 2019, 's
# Killian of Bettunnyent':r': 'none': 'orce': eoc': ce
# Killian of Neult inder': ':onger': ': usk: 'source':
# Killian of Mee
# LVScignyn of QGewander': 'jor': er': 'jrace': uste':':
# LVScignyn of W an ex
# LVScignyn of EnsJimanna iskeri:
# LVScignyn of R
# LVScignyn of T yn
# LVScignyn of Ysor': 'ar': ': ': unt': 6ence': 's 9sami
# LVScignyn of Uson: ces': 'source': 'US census'} Daless
# LVScignyn of I
# LVScignyn of O cher
# LVScignyn of Paunem: es':mele ': ces': ccoc': ust': ce
# LVScignyn of Asr':ker': ': 'source': 'UUM ce': 'US cen
# LVScignyn of S
# LVScignyn of Dar's uman': 'source': 'US census'} Marxa
# LVScignyn of Flansar': ': 'source': 'so1rce': 'US cens
# LVScignyn of Garne ya
# LVScignyn of Hi: ': 'j: 'source': ': ce'st'r's urc ':
# LVScignyn of Jes cha
# LVScignyn of KDwannanes': 'source': ': coman': 'soc ':
# LVScignyn of Lansore': ': t 'source': 'source': 'US ce
# LVScignyn of Zynal echania
# LVScignyn of XD DDKurces ': census'} Darian
# LVScignyn of Cras': 'somec': 'socec': 'socrce': 'sourc
# LVScignyn of Valdwi: 'nour': 'jSmar': teman': 1960, 's
# LVScignyn of B:1Devert :'source': ':onr': ':'c 'emc te
# LVScignyn of Naus
# LVScignyn of Mansanangsos': 'source': 'US census'} Rex
# ZRuhan of Qale
# ZRuhan of W ar
# ZRuhan of Eld ila er
# ZRuhan of Rals sher
# ZRuhan of Taagan issa
# ZRuhan of Ya
# ZRuhan of Uallkannandailengannames': 'sures': 'sour
# ZRuhan of I
# ZRuhan of O an
# ZRuhan of Panma isha
# ZRuhan of Alldeur': ':kur': 'source': 'jrpe 's urce
# ZRuhan of Sialeur cnnanduar': ': cender': 'F', 'sou
# ZRuhan of Dalmas eria
# ZRuhan of Fris anna lia
# ZRuhan of Gallene escia
# ZRuhan of Heis ellia
# ZRuhan of Jian
# ZRuhan of Ka
# ZRuhan of Lans ' ansus ': 'source': ': ': 's urce'
# ZRuhan of Zale
# ZRuhan of Xa anie
# ZRuhan of Capell uminuar': 'source': 'jr2a ': cesu
# ZRuhan of Vale ard
# ZRuhan of Bander': 'source': ': ar': 'source': 's u
# ZRuhan of Nauma ancela
# ZRuhan of Manna
# XVV8m:t'source': of Q Su8si:
# XVV8m:t'source': of W erce': 'n1pece': c 1iche ce's 8icthandw
# XVV8m:t'source': of Er': cec'n 11676 , ssust'} Lynder
# XVV8m:t'source': of R uscesic 'sisrasiamerkalesel: 's'urce':
# XVV8m:t'source': of T'yri: 's 19: 'e ce': 1918, 'source': 'US
# XVV8m:t'source': of Yrce': cece's'u census':
# XVV8m:t'source': of U: cene'} Dia
# XVV8m:t'source': of Ir':': 's'T ami
# XVV8m:t'source': of Or': er': 'US census'} Jaccour
# XVV8m:t'source': of Pr16: cec'e 's11nce's'} Tenis
# XVV8m:t'source': of Arce': er': 's cinder
# XVV8m:t'source': of S'cece':'} Artan
# XVV8m:t'source': of D: c cem:'} Thorar
# XVV8m:t'source': of Fr'a'c ': ceces'} Alianita
# XVV8m:t'source': of Grurac': 1695, 'source': 'US census'} Dia
# XVV8m:t'source': of He's urces'} Daulton
# XVV8m:t'source': of Jeranche i
# XVV8m:t'source': of Kerce': nnoge': 9Amer': 19c6, 'source':
# XVV8m:t'source': of L: 1nnece': ceces'} Balder
# XVV8m:t'source': of Z ercanses': 9:r'ncas': 'sour':': 'd c ':
# XVV8m:t'source': of X:11epe'} Dwanic
# XVV8m:t'source': of Corrce': '15, 'source': 'US census'} Daid
# XVV8m:t'source': of V Thamilus
# XVV8m:t'source': of Br8: 'US census'} Daulte
# XVV8m:t'source': of Nece':': census'} Damari
# XVV8m:t'source': of M'ce': 'rmc 'npc es'} Anna
# Cherve of Queemimem:t'sore': er': 's urce': ':mcbem
# Cherve of Wems ellu
# Cherve of Eldesmi: ': warc's' Escie
# Cherve of R
# Cherve of T as
# Cherve of Ysial er
# Cherve of Ugmyeden:': 1 ': nece': 'source': 'noce':
# Cherve of I
# Cherve of Oses er'sumi: ': 'sour': ': 'source': 'Ur
# Cherve of Pituch: andes': 'sor': 'source': 'source'
# Cherve of Asgeis M': 'sous': ': 'source': 'jr3: 'so
# Cherve of S ies
# Cherve of Dag's emm:t'sorrc:': 'source': 'source':
# Cherve of Fle er
# Cherve of Gallere vis
# Cherve of Heghur es gtheria
# Cherve of Jis
# Cherve of Kegge
# Cherve of Lexer 1 eric
# Cherve of Zee
# Cherve of XM1chcucci: cest': 1 'sumet': 5stcensus'}
# Cherve of Cimec'um: censume':': 'source': 'npc mame
# Cherve of Velgtern werdene
# Cherve of Better: ': 'sour': ': ce': 'socrce': 'US
# Cherve of Negre
# Cherve of Mis Ageer': 'source': 'gr's'2b: 'source':
# V0γdjorc of QS1199ctonde9: gece':': 'source': 'j8S ce
# V0γdjorc of Wetquip ': 'source': ': census'} Dettie
# V0γdjorc of Esckes': ':onece': ce't', 'source': 'US c
# V0γdjorc of RSpequure': 'USkconsos': 'source': 'US ce
# V0γdjorc of T'orge': ':ker': 'U2kor': 2818, 'source':
# V0γdjorc of Yn: 'soer': ': ce': 'noce': gngr':': 'sou
# V0γdjorc of Uge'none': '89r': nont': 1or': 1983t '99e
# V0γdjorc of Inchorce': ':oce'sonr': 'source': 'j2, 's
# V0γdjorc of Onsec': cec': ces':r'soce': ':oce': '99c
# V0γdjorc of P:nst': ce'sor ': 'US census'} Dorachia
# V0γdjorc of Asocgce': cec': ce': c09ctcence':'Mscoce'
# V0γdjorc of St19: 'source': 'US census'} Donnie
# V0γdjorc of D:w1mesu:': 'source': 'U: census'} Lady
# V0γdjorc of Fnisc': ce'sourc': ': 'U: 'ecce': ': 20t
# V0γdjorc of Getry': 'es': cec': 1sosc': cene':'} Denc
# V0γdjorc of Hede ': ': ce'source': 'US cender': 'sour
# V0γdjorc of Jences': ':onec': t': 'source': 'r1c ': '
# V0γdjorc of Knri: 'socece': 'Dorce': 'j209: 'source':
# V0γdjorc of L:ource'g': 'socrce': 'joce': 19c 'nt'cou
# V0γdjorc of Z399:t'source': 'r'g 'source': 'S'c cece'
# V0γdjorc of XMecgensur': 'source': 'US census'} Uldia
# V0γdjorc of Comen': 'U:kcensumet'} Lingus
# V0γdjorc of V891t'source': ': ce'source': 1913, 'sour
# V0γdjorc of B:899t er': censome': 'Sogen': census'} D
# V0γdjorc of Netcer': 'socr': ': ce': cences'} Alisy
# V0γdjorc of Mont 'source': ': ce': 'US census'} Daxen
# Brot'ye':': of Q Goderd
# Brot'ye':': of Wonon': ': 'n': 'eog': gnor': 'M', 'sourc
# Brot'ye':': of En': 19k0, 'source': 'spurtem:
# Brot'ye':': of Roros': 'e ': 'sour':': 'jru:e': 'U: 'y'e
# Brot'ye':': of T'isos ': ': 1em016, 'source': 'US census
# Brot'ye':': of Y': 'sour':': 'er': 'US census'} Garret
# Brot'ye':': of U: 'z1Ge/Be0esi: ich
# Brot'ye':': of I'source': 's'Grottis
# Brot'ye':': of O'g'e ': 1e'' ': '8Me':': 'source': 'US c
# Brot'ye':': of Por': 'U0 geno'e': 'nog ': 'zome ender
# Brot'ye':': of Ar': 'Ur 'n': 'e'c ': 1988: 'source': 'US
# Brot'ye':': of S'g es'} Mozme
# Brot'ye':': of D: 'noge':': 'source': 'US census'} Alexi
# Brot'ye':': of F'gender': '0o1t': 118' ': 'yend': 2016,
# Brot'ye':': of G0org': t'emengenon':'L5, 'source': 'sour
# Brot'ye':': of He': 'US census'} Doland
# Brot'ye':': of Jemunan': 1 99:7, 'sour': ': er': 'US 'on
# Brot'ye':': of Knorke esse
# Brot'ye':': of L: 'n'g 'source': 'US census'} Agron
# Brot'ye':': of Zo'rce': 'U1 'n gen': 'n': 'source': 'US
# Brot'ye':': of X: 11y': 2er': '10, 'source': 'US census'
# Brot'ye':': of Comor': ':/'encender': 'source': 'npc iso
# Brot'ye':': of V001es'} Gomme
# Brot'ye':': of Br': ': 1e': 'npg isourge': 'n gng'e ': 2
# Brot'ye':': of N'or': ': 19z0eydern: 2anem: neman': Le n
# Brot'ye':': of M': 's'3rnd': '0zja 'souru:e': 'US census
# N'one of Qe19: 'geter': '1kurk: 'source': 'US cens
# N'one of Winnar': 'sour': ': cenden': 'suurce': 'U
# N'one of Elf el: vin
# N'one of Ree
# N'one of T e pei: 'e us ': 'source': ': ce': c 'an
# N'one of Yell:w'rat':onec': censuc': 'source': 'US
# N'one of UV 0089b: 1sansure': 'source': 'nrcece':
# N'one of Innanell: 'janharman': 'source': 'US cens
# N'one of O': elender': 'Fond': 'jS 'sour': 'US cen
# N'one of Pamccest':man': cence': 'source': 'US cen
# N'one of Ar': 'nour': ': usu': emale 'M'g 'emur':
# N'one of S 9:r'sourc': 'jr8: 'jorce': 'F', 'source
# N'one of Dw9:'cenem: 'jomethalflengnurce': 1oce':
# N'one of Fle1n: ant urg': 113, 'year
# N'one of Galle eriquu
# N'one of He Fi:uarn: ': ce': uman': 'nt': 'suur':
# N'one of Janna echa
# N'one of Kell: 'agnd ': 'j: 'joun ': 'nour': 'US c
# N'one of L59:unedece': esus 'jamcene':':our': 'erc
# N'one of Zeedwar'none':': 'suce': 'kont': umi: 'U9
# N'one of XV119: 'source': ': censur': 'socrce': 'U
# N'one of Chammemen: 9:belt': 1unt': urce': 'erce'
# N'one of Vathenar': 'ane ': cender': 'source': 'n
# N'one of Bannes': 'sour': ': census'} Nolan
# N'one of Nadeu: ': 'joce': 'jS 2ece': 1r's3c or':
# N'one of Mancen:': 1eder': 'source': 'noge': ' ce
# M'ed': of QoSo mines'} Ton
# M'ed': of Welongnur': ': 1int': 1er': '00, 'source'
# M'ed': of En': 4ar': 'M census'} Meghon
# M'ed': of Rours': 'j00, 'source': 'US census'} Elst
# M'ed': of T'Fe'son meck
# M'ed': of Y'c 'source': 'US census'} Nickiel
# M'ed': of U: 2006, 'source': 'US census'} Nalista
# M'ed': of I'source': 'US census'} Elston
# M'ed': of O's ur': ': 2ele 'F', 'source': 'npc fema
# M'ed': of Porce': 'US census'} Jansaur
# M'ed': of Ar': 'M', 'source': 'npc male gnome'} Nam
# M'ed': of S'source': 'US census'} Josequiel
# M'ed': of Deran': 2012, 'source': 'US census'} Jail
# M'ed': of F', 'source': 'npc male human'} Vigfar
# M'ed': of Gurc': 'npc male elf'} Araol
# M'ed': of Hwarf': 200, 'year': 2010, 'source': 'US
# M'ed': of JMorender
# M'ed': of Keros'} Ebriko
# M'ed': of Longnust': 1, 'source': 'jS census'} Nora
# M'ed': of Zource': 'US census'} Zellie
# M'ed': of XMount': 19, 'year': 1880, 'source': 'US
# M'ed': of Coron': 'n ce's'Lomander
# M'ed': of V020ope': gnor': 'US census'} Rexx
# M'ed': of Bu2: ': 1887, 'source': 'US census'} Neve
# M'ed': of N'orn:': 14, 'year': 1975, 'source': 'US
# M'ed': of M': 6, 'year': 1941, 'source': 'US census

# %%
place
# Out:
# ['Qegre',
#  'Warns',
#  'Els',
#  'Raly',
#  'Thalmarc',
#  'Ya',
#  'UShancant',
#  'I',
#  'Oman',
#  'Palhandem:',
#  'Ald',
#  "Shaminder':",
#  "DallsPi:t's'8an':",
#  'Farcha',
#  'Galvi',
#  'Hl0:',
#  'Jalla-PKfidras',
#  'Kanna',
#  'Laphari:',
#  'Zalmas',
#  'Xa',
#  "Car':",
#  'Vall',
#  'Bardi:',
#  'Nan',
#  'Mangel',
#  "QiXS1mannus':",
#  'Wim:',
#  "Ensemar':",
#  'Rikb:',
#  "T'anger':",
#  'Ysevi:',
#  "UMmar':r':':",
#  "Ince's",
#  "Onder':",
#  "Peur':",
#  "Asrckar':",
#  "Sman':",
#  'Dami:',
#  "Fleuer':",
#  "Girr':",
#  'HlJumi:',
#  'Jenstria',
#  "Keles':",
#  'LX0119:',
#  "Zerker':",
#  'XS',
#  "Crancust':rus",
#  'Valinus',
#  'Berm:l:',
#  "Neur':",
#  "Mi:ces':",
#  'Quimi',
#  'Wis',
#  'Elko',
#  'Ruum',
#  'T',
#  'Yus',
#  'UMoni:',
#  'I',
#  'O',
#  'Pans',
#  "As':",
#  'S',
#  'Daugh',
#  'Finlang',
#  'Ganleug',
#  'Hiand',
#  'Jiald',
#  'KVimans',
#  'Luuf',
#  'Zumin',
#  'XIV',
#  'Cher',
#  'Valluus',
#  "Bunthernur':",
#  'Nana',
#  'Mansuma',
#  'Qe11',
#  'Wal:',
#  "Est':",
#  'R',
#  'T',
#  'Yang',
#  "U:moroce':",
#  'I',
#  "O'snce':",
#  "Pi:t'sor':",
#  "Asker':",
#  "S9:e'sourc':",
#  'Dahumi:',
#  'Fyns',
#  'Giand',
#  "Hes':",
#  'Jennsus',
#  'Krans',
#  "Ligns':",
#  'ZhInna',
#  'XI',
#  'Carnis',
#  "Vellous':",
#  'Bome',
#  'Nann',
#  "Mesas'Fer':",
#  "QuMorges'}",
#  "We8r':",
#  "Enear':",
#  "Ruurce':",
#  'T',
#  "Yr':",
#  'U:',
#  "Ir'n':",
#  "O'g",
#  "Pr'a",
#  "Ar':",
#  "Soce':",
#  "D:pendar':",
#  "Fe'r':",
#  "Gronan':':",
#  "He':",
#  'J',
#  'Knorcen:',
#  'L:',
#  'Z',
#  'X:',
#  "Cruran':",
#  "V01us':",
#  'Bruut',
#  "Nece':",
#  "Mr':':",
#  "Quuur'}",
#  "W'M',",
#  "Es'uounce'",
#  "Ruurc':",
#  "T'F'sonnus':",
#  "Y'source':",
#  "UF',",
#  "I'source':",
#  "O'c'n",
#  "Pur':",
#  "Alir':",
#  "S'M',",
#  "DM',",
#  "F',",
#  "GFring'}",
#  "Her':",
#  'JF',
#  "Kernnu':",
#  "LM',",
#  'Z',
#  'XM',
#  "Cor'e':",
#  'V01',
#  "Burpe':",
#  "N'urce':",
#  "M'source':",
#  "Qu4emen'e'}",
#  "W'source':",
#  'E',
#  'R',
#  "T'ist's'8st'ian",
#  "Yn'r':",
#  'Ur',
#  "I'gndender':",
#  "O'gnnnus'}",
#  "Pnnnus'}",
#  "Ander':",
#  "S'188",
#  "Dunn':",
#  "F'c",
#  "Gunn':",
#  "Hen'd's",
#  'J88s9a',
#  "Knust'}",
#  'L88s',
#  "Z'Doris",
#  'Xn',
#  "C'ar':",
#  'V088s',
#  "Br'n",
#  "N'sour's':",
#  "Mnnn's'irge",
#  'Q',
#  'W',
#  "Es'urce':",
#  'R',
#  "T'urc':",
#  "Y'source':",
#  'Us',
#  "I'wwum:",
#  "O's's",
#  "Puar':",
#  "As's",
#  'S',
#  "Duran':",
#  "F'source':",
#  "Gura':",
#  "Her'F'source':",
#  'Jenna',
#  'Kuple',
#  'Lw978,',
#  "Z'S",
#  'XF',
#  "C'aris",
#  'V',
#  "Bwar':",
#  "N'sor':':",
#  "M'source':",
#  'Quim',
#  'Wans',
#  'Eliand',
#  'Rela',
#  'Tiand',
#  'Y',
#  'Ualm09:',
#  'I',
#  'O',
#  'Piant',
#  'Aln',
#  'S',
#  'Dauma',
#  'F',
#  'Ga',
#  'Hii:',
#  'Ji0le',
#  'Ka',
#  'Lainoc',
#  'Zian',
#  'XSmathe',
#  "Car':",
#  'Vanla',
#  "Bamilduan':",
#  'Naus',
#  "Mansuma':",
#  "Qoomis'V",
#  'Wonrkel:',
#  "Er':pevilg'}",
#  "Rourt':",
#  "Tour':",
#  "Yong':",
#  'U:',
#  "Ilgngono':'}",
#  "O'gr':'}",
#  "Pope':",
#  "As'y",
#  "Socwmr'}",
#  'Dorkel:',
#  "Fr'apes'}",
#  'Gorv:',
#  "Hworce':",
#  "Jous'}",
#  "Kong'}",
#  'LUS',
#  "Zourker':",
#  'Xopc',
#  "Coros'}",
#  "Voros'}",
#  "Borc':",
#  "Noas'}",
#  "Mogr':pS",
#  "Quuumen'}",
#  "W'alc",
#  "Er':",
#  "Ruurc':",
#  "T'orce':",
#  "Y'urce':",
#  'U:',
#  "I'g'n",
#  "O''",
#  "P'','ce's",
#  "Ar':",
#  "S'c",
#  'DF',
#  "F'gen'e",
#  "Gur':",
#  "He'g'}",
#  "Jer'c",
#  "Kur':",
#  'Lo',
#  "Zuur':':",
#  'XF',
#  "Cume':",
#  'Vameli',
#  "Burce':",
#  "N'or':",
#  "M'c",
#  'Quelw29:',
#  'W',
#  "Ege':",
#  'Reuc',
#  'T',
#  'Y',
#  "U89:durces':",
#  'I',
#  "O'g",
#  "PF9:t'emer':",
#  'Arri:',
#  'S',
#  "DFweisgnurc':",
#  'F',
#  "Ganger':",
#  "Hexut':",
#  'Jer',
#  'Kanne',
#  "L99unnet':",
#  "Zewi:':",
#  "XMancathes':",
#  "Car':",
#  'Vale',
#  'Br9:',
#  'Ni:',
#  "Mes':",
#  'Quim',
#  'Wasian',
#  'Es',
#  'Rusi:',
#  'T',
#  'Ya',
#  "Usagsor':",
#  'I',
#  'O',
#  'Pist',
#  'Asal:',
#  'S',
#  'Daugelis',
#  'Farla',
#  'Gera',
#  'Hail',
#  'Jia',
#  'Karmus',
#  'Lashale',
#  'Zee',
#  'XS',
#  'Cia',
#  'Valil',
#  'Biaf',
#  'Naus',
#  'Malia',
#  "Qourmen'}",
#  'Whale',
#  "Er'g',",
#  "Rourc':",
#  "T'irce':",
#  "Yr'o':",
#  'UM',
#  "I'gnunc'}",
#  "O'gr':",
#  "Por's",
#  "Ar':",
#  "S'Monder':",
#  "Dorce':",
#  "F'source':",
#  "Gorr':",
#  "Hwarf':",
#  'JwS',
#  "Konnnor':",
#  'LF',
#  "Z'Fonna",
#  'XM17,',
#  "Coman'e':",
#  'V0Ewnny',
#  "Bwarf':",
#  "N'urce':",
#  "M'M",
#  "Quintras'ut'}",
#  "Wess'}",
#  "Ester':",
#  "Ronet'yng':",
#  "T'sour':",
#  "Yncine':",
#  "Ugender':",
#  "Ingnust':",
#  "Onger':",
#  "P.onges':",
#  "Asource':",
#  "St':r'ec':",
#  "Dernander':",
#  "Fesor':",
#  'Genti:',
#  "Hender':",
#  "Jeniander':",
#  "Kennender':",
#  "Leuge':':",
#  "Zouce':",
#  "XInter':',",
#  "Ciman':",
#  "Vandisu:der':",
#  "Beman':",
#  "Nest':'gnes'eru:",
#  "Mensor':",
#  "Quuer'e",
#  'Wele',
#  'Enel:',
#  'Resumi:',
#  "T'epen",
#  'Yusece',
#  'Us',
#  "Inders':",
#  "Onesus'",
#  "Pemer':",
#  "Acker':",
#  'Sonechum:',
#  "Durce':",
#  "Fleonder':",
#  'Guri:',
#  "Her':",
#  'Jume',
#  'Kupin',
#  "Lelgenus'}",
#  'Z',
#  'Xu3a',
#  'Ceneri:',
#  'Vesenelia',
#  "Ber':",
#  'Nemuma',
#  "Me's",
#  'Quea',
#  'Ward',
#  'Esia',
#  'Risia',
#  'Ta',
#  'Ya',
#  'Ueme',
#  'In',
#  'Oces',
#  'Pamo',
#  'As',
#  'Sil',
#  'De',
#  'Fla',
#  'Gill',
#  'High',
#  'Jinbi',
#  'Ke',
#  'Linn',
#  'Zee',
#  'Xa',
#  'Cine',
#  'Vont',
#  'Barl',
#  'Nais',
#  'Minia',
#  'Qeer',
#  'Walige',
#  "EMle':",
#  'Rens',
#  'T',
#  "Yenpuou':",
#  "Uercer':one':':",
#  'I',
#  'O',
#  "Peteres':",
#  'Ageen',
#  'S',
#  'De',
#  'Fe',
#  'Ge',
#  'He',
#  'Jells1eant',
#  'Kian',
#  "Leus':",
#  'Zeer',
#  "Xencet'e",
#  'Come',
#  'Velltwande',
#  "Bettunnyent':r':",
#  'Neult',
#  'Mee',
#  "QGewander':",
#  'W',
#  'EnsJimanna',
#  'R',
#  'T',
#  "Ysor':",
#  'Uson:',
#  'I',
#  'O',
#  'Paunem:',
#  "Asr':ker':",
#  'S',
#  "Dar's",
#  "Flansar':",
#  'Garne',
#  'Hi:',
#  'Jes',
#  "KDwannanes':",
#  "Lansore':",
#  'Zynal',
#  'XD',
#  "Cras':",
#  'Valdwi:',
#  'B:1Devert',
#  'Naus',
#  "Mansanangsos':",
#  'Qale',
#  'W',
#  'Eld',
#  'Rals',
#  'Taagan',
#  'Ya',
#  "Uallkannandailengannames':",
#  'I',
#  'O',
#  'Panma',
#  "Alldeur':",
#  'Sialeur',
#  'Dalmas',
#  'Fris',
#  'Gallene',
#  'Heis',
#  'Jian',
#  'Ka',
#  'Lans',
#  'Zale',
#  'Xa',
#  'Capell',
#  'Vale',
#  "Bander':",
#  'Nauma',
#  'Manna',
#  'Q',
#  'W',
#  "Er':",
#  'R',
#  "T'yri:",
#  "Yrce':",
#  'U:',
#  "Ir':':",
#  "Or':",
#  'Pr16:',
#  "Arce':",
#  "S'cece':'}",
#  'D:',
#  "Fr'a'c",
#  "Grurac':",
#  "He's",
#  'Jeranche',
#  "Kerce':",
#  'L:',
#  'Z',
#  "X:11epe'}",
#  "Corrce':",
#  'V',
#  'Br8:',
#  "Nece':':",
#  "M'ce':",
#  "Queemimem:t'sore':",
#  'Wems',
#  'Eldesmi:',
#  'R',
#  'T',
#  'Ysial',
#  "Ugmyeden:':",
#  'I',
#  'Oses',
#  'Pituch:',
#  'Asgeis',
#  'S',
#  "Dag's",
#  'Fle',
#  'Gallere',
#  'Heghur',
#  'Jis',
#  'Kegge',
#  'Lexer',
#  'Zee',
#  'XM1chcucci:',
#  "Cimec'um:",
#  'Velgtern',
#  'Better:',
#  'Negre',
#  'Mis',
#  'QS1199ctonde9:',
#  'Wetquip',
#  "Esckes':",
#  "RSpequure':",
#  "T'orge':",
#  'Yn:',
#  "Uge'none':",
#  "Inchorce':",
#  "Onsec':",
#  "P:nst':",
#  "Asocgce':",
#  'St19:',
#  "D:w1mesu:':",
#  "Fnisc':",
#  "Getry':",
#  'Hede',
#  "Jences':",
#  'Knri:',
#  "L:ource'g':",
#  "Z399:t'source':",
#  "XMecgensur':",
#  "Comen':",
#  "V891t'source':",
#  'B:899t',
#  "Netcer':",
#  'Mont',
#  'Q',
#  "Wonon':",
#  "En':",
#  "Roros':",
#  "T'isos",
#  "Y':",
#  'U:',
#  "I'source':",
#  "O'g'e",
#  "Por':",
#  "Ar':",
#  "S'g",
#  'D:',
#  "F'gender':",
#  "G0org':",
#  "He':",
#  "Jemunan':",
#  'Knorke',
#  'L:',
#  "Zo'rce':",
#  'X:',
#  "Comor':",
#  "V001es'}",
#  "Br':",
#  "N'or':",
#  "M':",
#  'Qe19:',
#  "Winnar':",
#  'Elf',
#  'Ree',
#  'T',
#  "Yell:w'rat':onec':",
#  'UV',
#  'Innanell:',
#  "O':",
#  "Pamccest':man':",
#  "Ar':",
#  'S',
#  "Dw9:'cenem:",
#  'Fle1n:',
#  'Galle',
#  'He',
#  'Janna',
#  'Kell:',
#  "L59:unedece':",
#  "Zeedwar'none':':",
#  'XV119:',
#  'Chammemen:',
#  "Vathenar':",
#  "Bannes':",
#  'Nadeu:',
#  "Mancen:':",
#  'QoSo',
#  "Welongnur':",
#  "En':",
#  "Rours':",
#  "T'Fe'son",
#  "Y'c",
#  'U:',
#  "I'source':",
#  "O's",
#  "Porce':",
#  "Ar':",
#  "S'source':",
#  "Deran':",
#  "F',",
#  "Gurc':",
#  "Hwarf':",
#  'JMorender',
#  "Keros'}",
#  "Longnust':",
#  "Zource':",
#  "XMount':",
#  "Coron':",
#  "V020ope':",
#  'Bu2:',
#  "N'orn:':",
#  "M':"]

# %%
G = list(filter(lambda name: name[0] == "G", place))
G.sort()
G
# Out:
# ["G0org':",
#  "GFring'}",
#  'Ga',
#  'Galle',
#  'Gallene',
#  'Gallere',
#  'Galvi',
#  "Ganger':",
#  'Ganleug',
#  'Garne',
#  'Ge',
#  'Genti:',
#  'Gera',
#  "Getry':",
#  'Giand',
#  'Gill',
#  "Girr':",
#  "Gorr':",
#  'Gorv:',
#  "Gronan':':",
#  "Grurac':",
#  "Gunn':",
#  "Gur':",
#  "Gura':",
#  "Gurc':",
#  'Guri:']

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Naus', 'Zynal', "Mesas'Fer':", 'Jume', "Zouce':", "Mansuma':",
#        "QuMorges'}", "Yong':", "N'sour's':", 'Daugelis'], dtype='<U26')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(["Ruurc':", 'I', 'I', 'Daugh', "DM',", "Pnnnus'}", "Es'urce':",
#        'Lexer', 'LF', 'Reuc'], dtype='<U26')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Fris', "Mensor':", "O'g", "Z399:t'source':", "F'gender':",
#        "Lelgenus'}", 'Valinus', 'Elko', 'Jenna', 'T'], dtype='<U26')

# %%
generate_names()
# Out:
# ["Qu>hal samender': 'M'",
#  'Wφym wel',
#  'Es-uIng w',
#  'RLumunchia',
#  "T'oran",
#  "Y'gennur': 'M', 'source': 'npc male dwarf",
#  "U: nder': 'n8, 'source': 'npc male elf'}",
#  "I'gender': uma 's'M aver",
#  "O'gngne Der",
#  "Pminourc:': ance': 1vint'yla dwarp: 'Mpc",
#  "Ald': urce': 'nourc:': 1994, 'source': 'U",
#  "S'eechura': 'F'' 'gene': 'source': 'jr5,",
#  "Dw9rveneke S1ander': 'US census'} Ste",
#  "F'gender': 'F', 'source': 'npc female dwa",
#  'Gurva',
#  "Hwynde':': 1880: 'source': 'US census'} H",
#  'JJKy',
#  'K. Scieper',
#  "L,'source': 'source': 'source': 'US censu",
#  'ZçGil v',
#  "XV0, 'source': 'US census'} Gemma",
#  'Cherle',
#  'Viίxis er',
#  "Bro': ':': 'eo'e': 'doge': 'US 'epge's'}",
#  'Ncothal er',
#  "M': 'source': 'npc male human'} Minthar"]
