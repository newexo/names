# %%
import tensorflow as tf
# from tensorflow.keras.layers.experimental import preprocessing

import numpy as np
# import os
import time
# import pickle

# %%
from names import check, raw_data, vectorize, seq_model

# %%
chk = check.CheckPoint("jrpg_model")

# %%
model = chk.load()
model.compile_model()

# %% [markdown]
# ## Generate text

# %% [markdown]
# The simplest way to generate text with this model is to run it in a loop, and keep track of the model's internal state as you execute it.
#
# ![To generate text the model's output is fed back to the input](images/text_generation_sampling.png)
#
# Each time you call the model you pass in some text and an internal state. The model returns a prediction for the next character and its new state. Pass the prediction and state back in to continue generating text.

# %% [markdown]
# The following makes a single step prediction:

# %%
one_step_model = seq_model.OneStep(model)

# %% [markdown]
# Run it in a loop to generate some text. Looking at the generated text, you'll see the model knows when to capitalize, make paragraphs and imitates a Shakespeare-like writing vocabulary. With the small number of training epochs, it has not yet learned to form coherent sentences.

# %%
start = time.time()
result = one_step_model.generate(['Romeo '], 100)
end = time.time()
print(result)
print('\nRun time:', end - start)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.0.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.0.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.0.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).grus.1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).embedding.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).dense.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.0.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.0.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.0.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).grus.1.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# ['Romeo                                                                                                     ']
#
# Run time: 2.980433464050293

# %% [markdown]
# The easiest thing you can do to improve the results is to train it for longer (try `EPOCHS = 30`).
#
# You can also experiment with a different start string, try adding another RNN layer to improve the model's accuracy, or adjust the temperature parameter to generate more or less random predictions.

# %% [markdown]
# If you want the model to generate text *faster* the easiest thing you can do is batch the text generation. In the example below the model generates 5 outputs in about the same time it took to generate 1 above.

# %%
start = time.time()
states = None
result = one_step_model.generate(list("QWERTYUIOPASDFGHJKLZXCVBNM"), 100)
end = time.time()
for line in result:
    print(line.strip())
print('\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# Quan
# Werpin
# Eyper
# Rosse Mo.
# Treusa
# Yavel
# Unrk
# Iri
# Olivia
# Peprito
# A-Towa-Cant
# Shade
# D'lyhai
# Freidle and de Fanouiloy
# Great Hipharn
# Haujeric Bergh
# Joacin
# Kidus Brnithe
# Leno
# Zula
# Xanne Smader
# Cornelia
# Vaith
# Bert
# Numi'l Nachet
# Museri
#
#
# ________________________________________________________________________________
#
# Run time: 1.228646993637085

# %%
def generate_names(stem="", n=1):
    names = []
    for _ in range(n):
        states = None
        next_char = [stem + ch for ch in "QWERTYUIOPASDFGHJKLZXCVBNM"]
        next_char = tf.constant(next_char)
        result = [next_char]

        for n in range(40):
          next_char, states = one_step_model.generate_one_step(next_char, states=states)
          result.append(next_char)

        result = tf.strings.join(result)
        names += [" ".join([a.strip() for a in name.decode("utf-8").split() if len(a)]) for name in result.numpy()]
    return names

# %%
generate_names(n=10)
# Out:
# ['Queen of the Fais',
#  'Wardan',
#  'Etaneroux',
#  'Rielle Weepblance',
#  'Tyteh Ruskus',
#  'Yo King',
#  'Unzer',
#  'I asuri',
#  'Old Widve',
#  'Puffyy',
#  'Allaw Farresi',
#  'Sitru',
#  'Datokikh',
#  'Fordeth',
#  'Gilgamesh',
#  'Harnel',
#  'Jahm Wolarison',
#  'Kingsonm',
#  'Lanlighter',
#  "Zolaza'mhorg",
#  'Xakine',
#  'Corneliur',
#  'Vairemind',
#  'Bandaol',
#  'Nild Mandermill',
#  'Mayor Dor Snogh',
#  'Qualp Apequra',
#  'Wieth',
#  'Eyne Rel Fleurogh',
#  'Ryontrels of Fysch',
#  'Tressol Shelton',
#  'Yunia',
#  'Uapor',
#  'Ielbun',
#  'Ogalahm',
#  'Perchancel',
#  'Allone',
#  'Sayna',
#  'Deeh Ronso',
#  'Fryyn',
#  'Gilgamesh',
#  'Hall d',
#  'Jildagarte Felio',
#  'Kimas',
#  "Luh'tria",
#  'ZaiN Ligin',
#  'Xamk',
#  'Cloud of Lich',
#  'Val',
#  'Barret',
#  'Nana',
#  'Misear',
#  'Queen of the Trakassa',
#  'Wath Mascad',
#  'Eryns Garryn',
#  'Roginn and Qeren',
#  'Titus Deris',
#  'Yorn',
#  'Urbarro',
#  'Irkuire',
#  'Ornbord',
#  'Pah Uri',
#  'Ariania',
#  'Shad Noh',
#  'Dálin',
#  'Frugarn Tra',
#  'Gurdin',
#  "Ha'rhidde",
#  'Jolo',
#  'Kopa',
#  'Lo',
#  'Zun',
#  'Xandel',
#  'Curionos',
#  'Vyege',
#  'Burika',
#  'Norche',
#  'Mitris',
#  'Queen',
#  'Wedge',
#  'Eylan',
#  "R'nahna Rhaal",
#  'Thangoode',
#  'Yujin',
#  'Ureanué',
#  'Imnis Scivei',
#  "O'ccka",
#  'Peiry',
#  'Asu',
#  'Slari',
#  'Daunt Spord Goron',
#  'Fury',
#  'Greater',
#  'Herolod',
#  'Joper Soales',
#  'Komiov',
#  'Lubare',
#  'Zora Utara T',
#  'Xelton',
#  'Cie Fabool Vox',
#  'Victor Oakvers',
#  'Beede',
#  'Nuarvicine',
#  'Maile Braske',
#  'Quickthinx Hilder',
#  'Willvaulker',
#  'Exeller Blegork',
#  'Robah',
#  'Tino-Asheld',
#  'Yonn',
#  'Unsura',
#  'Isauko',
#  'Ovrich',
#  'Pumarion',
#  'Ariasha',
#  'Sidrer',
#  'Deliqo',
#  'Fratleyard Morh',
#  'Gabhain',
#  'Haurchief de',
#  'Julia',
#  'Katsura',
#  'Le-30',
#  'Zuh',
#  'Xalk d Fabool',
#  'Chiro',
#  'Vigett',
#  'Bunnie',
#  'Nultze Galrusca',
#  'Midris',
#  'Quale te Forteepes?',
#  'Waltz',
#  'Eyelh',
#  'Relia',
#  'Tinku',
#  'Yadd',
#  'Utahastra',
#  'Isaudor',
#  'Ordain',
#  'Parcha',
#  'Arcaricci',
#  'Stanice',
#  'Depp',
#  'Fider',
#  'Gurby',
#  'Harria',
#  'Jarbolk',
#  'Kata Gah',
#  'Larisza Leiny Gohs',
#  'Zober',
#  'Xas',
#  'Clarruson',
#  'Veyder Ouke',
#  'Bazee',
#  'Nacteus',
#  'Moston',
#  'Quall',
#  'Wergh',
#  'Elain',
#  'Relt',
#  'Tona',
#  "Y'ashtih Rikc",
#  'Ushar',
#  'Illa',
#  'Ola-Un',
#  'Patch',
#  'Azuz',
#  'Sayamaur',
#  'Duncion',
#  'Freyr',
#  'Grampo',
#  'Hurdy',
#  'Jane',
#  'Key',
#  'Lenar Fairy',
#  'Zell Dincht',
#  'Xonici',
#  'Casaliaas',
#  'Viltam',
#  'Bezg Bas Shiemet',
#  'Nar',
#  'Mikgair',
#  'Quell',
#  'Waltur',
#  'Eyper',
#  'Rainian',
#  'Tiacoto',
#  'Yuji',
#  'Uludari Aluaphi',
#  'Ibosh Seller',
#  'Oleil',
#  'Peppi',
#  'Amarasu',
#  'Sheot Gir',
#  'Dwee Staan',
#  'Fledna',
#  'Gustif',
#  'Henast of Windss',
#  'Joacin',
#  'Kerna Brook Bolleftor',
#  'Lili',
#  'Zell',
#  "Xoded'te Scrout",
#  'Canielji',
#  'Vinarde Mazar',
#  'Beqti',
#  'Nallich',
#  'Muir',
#  'Quana',
#  'Wlack Kagel',
#  'Ernyson Reve',
#  'Roll Dupis Colled',
#  'Tleuki',
#  'Yupui',
#  'Unche',
#  'Innucky',
#  'Old Man Aria',
#  'Paltia',
#  'Athyne',
#  'Strate',
#  'Dukinea',
#  'Folyur',
#  'Gilgamesh',
#  'Hydaleer',
#  'Joacin',
#  "Kill's Shaulow",
#  'Likki',
#  'ZDade Midibr',
#  'Xaza Mesta',
#  'Cachuia',
#  "Valent O'r Sian",
#  'Borsh',
#  'Noymu Habeo',
#  'Monia',
#  'Quien Kiene',
#  'Wlafess',
#  'Elgance Faircess',
#  'Rena-Lu',
#  'Tuffy Jerand',
#  'Yuki',
#  'Ul the Thelade',
#  'Istarakiep',
#  'Odrow Ttrao',
#  'Peppitaintu',
#  'Anaza',
#  'Stanik Alubov',
#  'Dr. Vevena',
#  'Fowbel',
#  'Great Beack',
#  'Hohahn Warrion',
#  'Joylon',
#  'Kihri',
#  'Luci-Ok',
#  'Zeld',
#  'Xanger wans',
#  'Choco Bay',
#  'Valensun',
#  'Brack',
#  "Nimia's Wipher",
#  'Megry']

# %%
generate_names('Joby of ', n=10)
# Out:
# ['Joby of Queen of Foreste',
#  'Joby of Wigder',
#  'Joby of Ellhert',
#  'Joby of Rince',
#  'Joby of Tie gesse',
#  'Joby of Yes',
#  'Joby of Uubrem',
#  'Joby of I Lounberr',
#  'Joby of Oulh',
#  'Joby of Peild',
#  'Joby of Aulum',
#  'Joby of Seller',
#  'Joby of Donsior',
#  'Joby of Fister',
#  'Joby of Giame',
#  'Joby of Histwlack',
#  'Joby of Jennus',
#  'Joby of Kelvert',
#  'Joby of Lions',
#  'Joby of Zelphie',
#  'Joby of Xepet',
#  'Joby of Cornel',
#  'Joby of Veuk',
#  'Joby of Burmecia',
#  'Joby of Nesser',
#  'Joby of Miphor',
#  'Joby of Queen',
#  'Joby of Wisdgeml',
#  'Joby of Ebling Order Fullam',
#  'Joby of Reber',
#  'Joby of Tiombr',
#  'Joby of Youges e Forresin',
#  'Joby of Ush',
#  'Joby of Iekel',
#  'Joby of Oel',
#  'Joby of PotlerI',
#  'Joby of Aulmer',
#  'Joby of Seller',
#  'Joby of Deller',
#  'Joby of Figes',
#  'Joby of Guard',
#  'Joby of Hindweld',
#  'Joby of Jembros',
#  'Joby of Kens',
#  'Joby of Lines',
#  'Joby of Zelder',
#  'Joby of Xe Hoillenarte',
#  'Joby of Chnie',
#  'Joby of Vigel',
#  'Joby of Belde',
#  'Joby of Nelo',
#  'Joby of Meille',
#  'Joby of Qeelpess',
#  'Joby of Wind',
#  'Joby of Elfheim',
#  'Joby of Resto',
#  'Joby of Tence',
#  'Joby of Yee',
#  'Joby of Ullend',
#  'Joby of I Mouitain',
#  'Joby of Oblin',
#  'Joby of Phi o',
#  'Joby of Abusaner',
#  'Joby of Seller',
#  'Joby of Delet',
#  'Joby of Fierds',
#  'Joby of Gind',
#  'Joby of Heirs',
#  'Joby of Jerm',
#  'Joby of Kav',
#  'Joby of Lulis',
#  'Joby of Zeepa',
#  'Joby of Xo',
#  'Joby of Cornelia',
#  'Joby of Vigler',
#  'Joby of Birds',
#  'Joby of Nesupi',
#  'Joby of Meir',
#  'Joby of Quon',
#  'Joby of Wints',
#  'Joby of Eurle',
#  'Joby of Reenos',
#  'Joby of Tisur',
#  'Joby of Yel',
#  'Joby of Uak',
#  'Joby of Ibusure',
#  'Joby of Oot',
#  'Joby of Peller',
#  'Joby of Allen',
#  'Joby of Siselle',
#  'Joby of Delger',
#  'Joby of Firel',
#  'Joby of Gerde Tulime',
#  'Joby of Heldor',
#  'Joby of Junser',
#  'Joby of Kinger',
#  'Joby of Lincet',
#  'Joby of Zeeper',
#  'Joby of Xiled Fener',
#  'Joby of Corlen',
#  'Joby of Vinderran',
#  'Joby of Bore',
#  'Joby of Nelv',
#  'Joby of Miluu',
#  'Joby of Queen',
#  'Joby of Worden',
#  'Joby of Edeng In',
#  'Joby of Rebl',
#  'Joby of Tor',
#  'Joby of Yee',
#  'Joby of Unbert',
#  'Joby of Icer Gorden',
#  'Joby of Ouscef',
#  'Joby of Pelle',
#  'Joby of Aulum',
#  'Joby of Selver',
#  'Joby of Delder',
#  'Joby of Funter',
#  'Joby of Gidbe',
#  'Joby of Highwind',
#  'Joby of Jurse',
#  'Joby of Kellwyr',
#  'Joby of Link',
#  'Joby of Zeepor',
#  'Joby of XM Foreles',
#  'Joby of Corden',
#  'Joby of Viwlle',
#  'Joby of Beir',
#  'Joby of Nug Falg',
#  'Joby of Me Poos',
#  'Joby of Quien of',
#  'Joby of Wirdson',
#  'Joby of Ebent Owner',
#  'Joby of Ree',
#  'Joby of Tibllers',
#  'Joby of Yire',
#  'Joby of Uberu',
#  'Joby of Ivilison',
#  'Joby of Oupur',
#  'Joby of Pistelll',
#  'Joby of Aobel',
#  'Joby of Salvesian',
#  'Joby of Denti',
#  'Joby of Fiendle',
#  'Joby of Girlo',
#  'Joby of Highwind',
#  'Joby of Jeus',
#  'Joby of Keemor',
#  'Joby of Link',
#  'Joby of Zewer',
#  'Joby of X Forrest',
#  'Joby of Crest',
#  'Joby of Vigee',
#  'Joby of Burter',
#  'Joby of Nukius',
#  'Joby of Midig',
#  'Joby of Queen',
#  'Joby of Wirds',
#  'Joby of Eurel',
#  'Joby of Ribes',
#  'Joby of Tione',
#  'Joby of Yen',
#  'Joby of Uste',
#  'Joby of Iise',
#  'Joby of Own',
#  'Joby of Poiles',
#  'Joby of Asthelt',
#  'Joby of Sibleng Pater',
#  'Joby of Dringess',
#  'Joby of Fie ge',
#  'Joby of Gordengoren',
#  'Joby of Highwind',
#  'Joby of Jimt',
#  'Joby of Kennd',
#  'Joby of Linsen',
#  'Joby of Zeeper',
#  'Joby of X Albucio',
#  'Joby of Corlyne',
#  'Joby of Velle',
#  'Joby of Blund Bird',
#  'Joby of Nise',
#  'Joby of Misters',
#  'Joby of Queen of ter Leviclo',
#  'Joby of Winds Wise',
#  'Joby of Ellen',
#  'Joby of Resse',
#  'Joby of Tinvelss',
#  'Joby of Yon',
#  'Joby of Ulone',
#  'Joby of Iburo',
#  'Joby of Ostle',
#  'Joby of Piver',
#  'Joby of Ablinosh',
#  'Joby of Seller',
#  'Joby of Delet',
#  'Joby of Fibhle',
#  'Joby of Gindy',
#  'Joby of Hinders',
#  'Joby of Jeonsy',
#  'Joby of Kingeros',
#  'Joby of Lien',
#  'Joby of Zelder',
#  'Joby of Xous',
#  'Joby of Celder',
#  'Joby of Venogi',
#  'Joby of Bubblip',
#  'Joby of Neper',
#  'Joby of Minder',
#  'Joby of Qeebers',
#  'Joby of Windsw nd Fander',
#  'Joby of Estheim',
#  'Joby of Res',
#  'Joby of Tienssen',
#  'Joby of Yell',
#  'Joby of U',
#  'Joby of Ito',
#  'Joby of Oberor',
#  'Joby of Piends',
#  'Joby of Auburner',
#  'Joby of Sigmess',
#  'Joby of Denter',
#  'Joby of Foriel',
#  'Joby of Gordensube',
#  'Joby of Hunter',
#  'Joby of Jinet',
#  'Joby of Kanss',
#  'Joby of Libss',
#  'Joby of Zelle',
#  'Joby of Xigne',
#  'Joby of Cornelo',
#  'Joby of Vevi',
#  'Joby of Belde Selen',
#  'Joby of Neuniol',
#  'Joby of Migger',
#  'Joby of Queen',
#  'Joby of Winds',
#  'Joby of Elder',
#  'Joby of Ruges',
#  'Joby of Tie',
#  'Joby of Yel',
#  'Joby of Uper',
#  'Joby of Iagrie',
#  'Joby of Oster',
#  'Joby of Peller',
#  'Joby of Ablan',
#  'Joby of Seller',
#  'Joby of Denfiurt',
#  'Joby of Fither',
#  'Joby of Gurdo',
#  'Joby of Highwan',
#  'Joby of Jenne',
#  'Joby of Kelder',
#  'Joby of Light',
#  'Joby of Zebes',
#  'Joby of X Porion',
#  'Joby of Cornel',
#  'Joby of Vineus',
#  'Joby of Burmerick',
#  'Joby of Neskor',
#  'Joby of Migus']

# %%
generate_names('Joby the ')
# Out:
# ['Joby the Qeoul ectra',
#  'Joby the Wedge',
#  'Joby the Eelle',
#  'Joby the Rubura',
#  'Joby the Te',
#  'Joby the Yakgo',
#  'Joby the Ulomer',
#  'Joby the Irondeart',
#  'Joby the Ooks',
#  'Joby the Poteus Be Hourema',
#  'Joby the Arotoh',
#  'Joby the Selign',
#  'Joby the Deepbell',
#  'Joby the Fonleynort',
#  'Joby the Goddess',
#  'Joby the Hitubutci',
#  'Joby the Jokenbul',
#  'Joby the Keeper',
#  'Joby the Lensinus',
#  'Joby the Zurnobert',
#  'Joby the XV Teer',
#  'Joby the Coutipe',
#  'Joby the Voiregon',
#  'Joby the Boss thiege',
#  'Joby the Neorna',
#  'Joby the Mountain']

# %%
place = []
for name in generate_names():
    name = name.split()[0]
    for long_name in generate_names(name + " of "):
        print(long_name)
        place.append(long_name.split()[2])
# Out:
# Queen of Quenn
# Queen of Wand
# Queen of Ebla
# Queen of Rent
# Queen of Tarlen
# Queen of Yenna
# Queen of Untter
# Queen of Ibaal
# Queen of Obraro
# Queen of Pinbel
# Queen of Abrin
# Queen of Shella
# Queen of Dart
# Queen of Fair
# Queen of Glenna
# Queen of Hart
# Queen of Jeanne
# Queen of Kinle
# Queen of Lentis Fa
# Queen of Zenfa
# Queen of Xex Fanro
# Queen of Cundisiny
# Queen of Velluta
# Queen of Black
# Queen of Nentin
# Queen of Mateer
# Welt of Qeen
# Welt of Walos
# Welt of Esthel
# Welt of Racch
# Welt of Trandtora
# Welt of Ybale
# Welt of Ungrol
# Welt of Igna
# Welt of Oki
# Welt of Pime
# Welt of Agena
# Welt of Salder
# Welt of Delep
# Welt of Fimile
# Welt of Gind
# Welt of Hilda
# Welt of Jink
# Welt of Kino
# Welt of Light
# Welt of Zord
# Welt of Xan
# Welt of Cinny
# Welt of Vineyard
# Welt of Birda Ph
# Welt of Necro
# Welt of Mage
# Ernelle of Qeven
# Ernelle of W. Kenny
# Ernelle of Eigre
# Ernelle of Ranson
# Ernelle of Torn
# Ernelle of Yors
# Ernelle of Ulents
# Ernelle of Itters
# Ernelle of Ois
# Ernelle of Premaru
# Ernelle of Althais
# Ernelle of Snoupes.
# Ernelle of Dagensst
# Ernelle of Farren
# Ernelle of Gyrls
# Ernelle of Hares
# Ernelle of Jerus
# Ernelle of Kirns
# Ernelle of Lansseld
# Ernelle of Zelda
# Ernelle of XV Almencup
# Ernelle of Chorw
# Ernelle of Vivess Seller
# Ernelle of Byrde
# Ernelle of Naulseer
# Ernelle of Maru
# Ragrnan-Fold of Quen
# Ragrnan-Fold of Wend
# Ragrnan-Fold of Elder
# Ragrnan-Fold of Rados
# Ragrnan-Fold of Tummler
# Ragrnan-Fold of Yupes
# Ragrnan-Fold of Ulddards
# Ragrnan-Fold of Instor
# Ragrnan-Fold of Opkrer
# Ragrnan-Fold of Pirmalps
# Ragrnan-Fold of Altheim
# Ragrnan-Fold of Salds
# Ragrnan-Fold of Dorneli
# Burtin of Xecre
# Burtin of Crescen
# Burtin of VuOre
# Burtin of Buged
# Burtin of Nayles
# Burtin of Menrins
# Nela's of Qean
# Nela's of Wenss
# Nela's of Ente
# Nela's of Req
# Nela's of Timf
# Nela's of Yer
# Nela's of Uiget
# Nela's of In
# Nela's of Owme
# Nela's of Pyr
# Nela's of Almene
# Nela's of Selle
# Nela's of Deurica
# Nela's of Ferle
# Nela's of Germall de
# Nela's of Hege
# Nela's of Jean
# Nela's of Kepper
# Nela's of Lengi
# Nela's of Zennous
# Nela's of Xe Mailmera
# Nela's of Cleur
# Nela's of Veser
# Nela's of Beart
# Nela's of Neca
# Nela's of Mesca
# Moudan of Qeelle
# Moudan of Wander
# Moudan of Edder
# Moudan of Rninsens
# Moudan of Travaire
# Moudan of Ymiges
# Moudan of Uta
# Moudan of IMina
# Moudan of Olviler
# Moudan of Perral
# Moudan of Almhnort
# Moudan of Soeles
# Moudan of Delvora
# Moudan of Flies
# Moudan of Girl
# Moudan of Hiliaus
# Moudan of Jrass
# Moudan of Kelders
# Moudan of Liges
# Moudan of Zerna
# Moudan of X Moogen
# Moudan of Churd
# Moudan of Vilea
# Moudan of Barel
# Moudan of Nerstell
# Moudan of Mirgon

# %%
place
# Out:
# ['Quenn',
#  'Wand',
#  'Ebla',
#  'Rent',
#  'Tarlen',
#  'Yenna',
#  'Untter',
#  'Ibaal',
#  'Obraro',
#  'Pinbel',
#  'Abrin',
#  'Shella',
#  'Dart',
#  'Fair',
#  'Glenna',
#  'Hart',
#  'Jeanne',
#  'Kinle',
#  'Lentis',
#  'Zenfa',
#  'Xex',
#  'Cundisiny',
#  'Velluta',
#  'Black',
#  'Nentin',
#  'Mateer',
#  'Qeen',
#  'Walos',
#  'Esthel',
#  'Racch',
#  'Trandtora',
#  'Ybale',
#  'Ungrol',
#  'Igna',
#  'Oki',
#  'Pime',
#  'Agena',
#  'Salder',
#  'Delep',
#  'Fimile',
#  'Gind',
#  'Hilda',
#  'Jink',
#  'Kino',
#  'Light',
#  'Zord',
#  'Xan',
#  'Cinny',
#  'Vineyard',
#  'Birda',
#  'Necro',
#  'Mage',
#  'Qeven',
#  'W.',
#  'Eigre',
#  'Ranson',
#  'Torn',
#  'Yors',
#  'Ulents',
#  'Itters',
#  'Ois',
#  'Premaru',
#  'Althais',
#  'Snoupes.',
#  'Dagensst',
#  'Farren',
#  'Gyrls',
#  'Hares',
#  'Jerus',
#  'Kirns',
#  'Lansseld',
#  'Zelda',
#  'XV',
#  'Chorw',
#  'Vivess',
#  'Byrde',
#  'Naulseer',
#  'Maru',
#  'Quen',
#  'Wend',
#  'Elder',
#  'Rados',
#  'Tummler',
#  'Yupes',
#  'Ulddards',
#  'Instor',
#  'Opkrer',
#  'Pirmalps',
#  'Altheim',
#  'Salds',
#  'Dorneli',
#  'Froes',
#  'Gadds',
#  'Hindwless',
#  'Jeans',
#  'Kind',
#  'Link',
#  'Zerne',
#  'Xen',
#  'Cornelia',
#  'Vanderon',
#  'Bordelus',
#  'Nandor',
#  'Miggle',
#  'Quent',
#  'Wel',
#  'Eulmore',
#  'Revelss',
#  'Tree',
#  'Yurmersop',
#  'Uuller',
#  'Itire',
#  'Oulure',
#  'Promes',
#  'Auburnin',
#  'Supmer',
#  'Duren',
#  'Fuire',
#  'Gurde',
#  'Hura',
#  'Jupis',
#  'Kurmers',
#  'Lugai',
#  'Zreas',
#  'Xenvr',
#  'Cinnyss',
#  'Vanner',
#  'Burmece',
#  'Nus',
#  'Minas',
#  'Quencen',
#  'Wilds',
#  'Estre',
#  'Ricks',
#  'Tinas',
#  'Yelfos',
#  'Uzle',
#  'Iken',
#  'Oken',
#  'Pille',
#  'Allan',
#  'Silless',
#  'Deltes',
#  'Fivey',
#  'Gindsan',
#  'Hictor',
#  'Jearblle',
#  'Kings',
#  'Lima',
#  'Zends',
#  'X',
#  'Cornel',
#  'Veva',
#  'Bendi',
#  'Nellain',
#  'Migage',
#  'Qeeper',
#  'Wed',
#  'Eid',
#  'Ran',
#  'Trader',
#  'Yar',
#  'Urder',
#  'Ider',
#  'Ord',
#  'Phil',
#  'Ari',
#  'Seller',
#  'Darns',
#  'Frac',
#  'Gartuc',
#  'Hugk',
#  'Jerand',
#  'Kars',
#  'Light',
#  'Zard',
#  'Xeka',
#  'Chief',
#  'Vell',
#  'Ber',
#  'Nu',
#  'Mukiu',
#  'Qeen',
#  'Wyrdger',
#  'Eblinose',
#  'Remqon',
#  'Timner',
#  'Ynn',
#  'Unter',
#  'Isine',
#  'Orvin',
#  'Pentain',
#  'Adran',
#  'Simler',
#  'Darnun',
#  'Ferrel',
#  'Goron',
#  'Heird',
#  'Jeans',
#  'King',
#  'Lings',
#  'Zeare',
#  'Xind',
#  'Conne',
#  'Vegro',
#  'Borol',
#  'Near',
#  'Mirale',
#  'Queen',
#  'Wanber',
#  'Eol',
#  'Reveille',
#  'Tir',
#  'Yen',
#  'Umicia',
#  'Indisu',
#  'Obba',
#  'Poving',
#  'Astral',
#  'Siger',
#  'Durtoie',
#  'Flac',
#  'Gurde',
#  'Harsbell',
#  'Jeamis',
#  'Kires',
#  'Light',
#  'Zabus',
#  'Xak',
#  'Carrus',
#  'Village',
#  'Bleddion',
#  'Nagi',
#  'Migita',
#  'Qeent',
#  'Walls',
#  'Elfheim',
#  'Revei',
#  'Tradissop',
#  'Yarus',
#  'Urtesman',
#  'Ickers',
#  'Oke',
#  'Piana',
#  'Astia',
#  'Stelas',
#  'Diges',
#  'Farress',
#  'German',
#  'Highwarg',
#  'Jeart',
#  'Kervols',
#  'Lisha',
#  'Zeeper',
#  'XV',
#  'Cleverson',
#  'Vigard',
#  'Bigts',
#  'Nesura',
#  'Miket',
#  'Queen',
#  'Wults',
#  'Edent',
#  'Rem',
#  'Terwal',
#  'Yemt',
#  'Ugent',
#  'Ing',
#  'Ouke',
#  'Phamuel',
#  'Alltion',
#  'SOlbert',
#  'Durmis',
#  'Furtess',
#  'Gurd',
#  'Hentriscin',
#  'Jusiun',
#  'Knick',
#  'Luinss',
#  'Zwers',
#  'XX',
#  'Corne',
#  'Vellert',
#  'Bukess',
#  'Nuis',
#  'Med',
#  'Queen',
#  'Winter',
#  'Elfhelt',
#  'Reles',
#  'Tineros',
#  'Yelda',
#  'Uller',
#  'Illdor',
#  'Otkeis',
#  'Piltsann',
#  'Astral',
#  'Silverran',
#  'Dreasen',
#  'Fishmeir',
#  'Guado',
#  'Hesto',
#  'Jeveil',
#  'Keeper',
#  'Lisk',
#  'Zelda',
#  'Xes',
#  'Cordbes',
#  'Vigak',
#  'Birdsman',
#  'Nesmis',
#  'Misaha',
#  'Qeen',
#  'Winds',
#  'Eze',
#  'Rincess',
#  'Tralin',
#  'Yang',
#  'Upia',
#  'Imica',
#  'Ondielle',
#  'Pille',
#  'Alena',
#  'Swend',
#  'Dark',
#  'Flan',
#  'Gehm',
#  'Heeral',
#  'Jewah',
#  'Ken',
#  'Lincis',
#  'Zarda',
#  'X',
#  'Cornelia',
#  'Villa',
#  'Blund',
#  'Na',
#  'Man',
#  'Q.el',
#  'Worts',
#  'Elfhers',
#  'Reeger',
#  'Toem',
#  'Yernus',
#  'Urner',
#  'IndiseX',
#  'Oserd',
#  'Phris',
#  'Allas',
#  'Shevalderson',
#  'Delds',
#  'Forest',
#  'Gurde',
#  'Hinds',
#  'Jeanes',
#  'Keder',
#  'Ligces',
#  'Zeeper',
#  'X/Finel',
#  'Cornelio',
#  'Velltas',
#  'Bed',
#  'Neles',
#  'Mirde',
#  'Qeven',
#  'Winds',
#  'Eblen',
#  'Risce',
#  'Tian',
#  'Yeqon',
#  'Upper',
#  'In',
#  'Oiter',
#  'Poreanio',
#  'Astral',
#  'Silvallan',
#  'Din',
#  'Flo',
#  'Graness',
#  'Herul',
#  'Jeane',
#  'Kindor',
#  'Legcca',
#  'Zedza',
#  'Xephie',
#  'Chief',
#  'Vilvalase',
#  'Bore',
#  'Nenring',
#  'Migage',
#  'Queen',
#  'Wont',
#  'Eckers',
#  'Rem',
#  'Thesker',
#  'Yamelue',
#  'Ugele',
#  'Iperi',
#  'Older',
#  'Pilvezast',
#  'Allana',
#  'Spra',
#  'Deveina',
#  'Forten',
#  'Gailsor',
#  'Heildart',
#  'Jeanie',
#  'Keele',
#  'Link',
#  'Zeeper',
#  'Xog',
#  'Coter',
#  'Vegs',
#  'Bordas',
#  'Ne',
#  'Mneise',
#  'Queen',
#  'Walds',
#  'Euburner',
#  'Reffeld',
#  'Tintersy',
#  'Yarsk',
#  'Utever',
#  'Indilia',
#  'Owlint',
#  'Phildanders',
#  'Astrol',
#  'Sment',
#  'Dornes',
#  'Fig',
#  'Gurde',
#  'Harke',
#  'Jeasta',
#  'Kindsen',
#  'Libas',
#  'Zeeper',
#  'Xblarch',
#  'Cheffl',
#  'Vineer',
#  'Barden',
#  'Nacke',
#  'Murie',
#  'Queen',
#  'Wadies',
#  'Elthe',
#  'Rel',
#  'Tramar',
#  'Yarun',
#  'Unshors',
#  'Ia',
#  'Octor',
#  'Pellan',
#  'Avina',
#  'Snaustin',
#  'Dellen',
#  'Futle',
#  'Gels',
#  'Hurter',
#  'Jarus',
#  'Kinjaros',
#  'Langess',
#  'Zeros',
#  'Xen',
#  'Cyrne',
#  'Van',
#  'Berel',
#  'Nevici',
#  'Migake',
#  'Qupee',
#  'Weld',
#  'Elder',
#  'Restis',
#  'Tradeiris',
#  'Yotce',
#  'Ullet',
#  'Ickers',
#  'Obrior',
#  'Pella',
#  'Alkhelt',
#  'Seller',
#  'Dark',
#  'Fane',
#  'Giany',
#  'Harvey',
#  'Jeana',
#  'Kinder',
#  'Lilk',
#  'Zeeper',
#  'Xal',
#  'Cornelia',
#  'Vigale',
#  'Byshe',
#  'Nabuea',
#  'Mani',
#  'Quen',
#  'Wint',
#  'Ellen',
#  'Ren',
#  'Trise',
#  'Yunet',
#  'Uplen',
#  'Ito',
#  'Oith',
#  'Philosophei',
#  'Aurcint',
#  'Sivler',
#  'Dyrul',
#  'Flain',
#  'Gabrany',
#  'Hyrule',
#  'Jun',
#  'Kiro',
#  'Lunner',
#  'Zanny',
#  'X',
#  'Creatinos',
#  'Vunare',
#  'Brindsa',
#  'Nake',
#  'Murmaci',
#  'Queen',
#  'Welts',
#  'Erder',
#  'Reace',
#  'Torne',
#  'Yeag',
#  'Uvine',
#  'Ivelle',
#  'Oava',
#  'Pimt',
#  'Augure',
#  'Spret',
#  'Delvelale',
#  'Five',
#  'Gurdy',
#  'Heru',
#  'Jerane',
#  'Kinds',
#  'Leveit',
#  'Zelda',
#  'Xe',
#  'Claudr',
#  'Via',
#  'Bulver',
#  'Nevairy',
#  'Melkus',
#  'Queen',
#  'Wander',
#  'Eugem',
#  'Rcveille',
#  'Terra',
#  'Yurserma',
#  'Uulve',
#  'Iugurne',
#  'Our',
#  'Phinganel',
#  'Augunna',
#  'Streef',
#  'Durres',
#  'Furtess',
#  'Gremon',
#  'Hinda',
#  'Jugles',
#  'Karn',
#  'Lugin',
#  'Zhan',
#  'Xfusii',
#  'Curgle',
#  'Vinana',
#  'Burbes',
#  'Nugus',
#  'Murtes',
#  'Quan',
#  'Whnb',
#  'Ester',
#  'Resto',
#  'Takera',
#  'Ya',
#  'Umi',
#  'Ive',
#  'Opper',
#  'Pmanisa',
#  'Alimada',
#  'Seller',
#  'Durmeria',
#  'Fla',
#  'Guado',
#  'Hon',
#  'Jen',
#  'Keek',
#  'Laven',
#  'Zelda',
#  'X',
#  'Carlus',
#  'VIv',
#  'Beqca',
#  'Ne',
#  'Magi',
#  'Queen',
#  'Walts',
#  'Erlen',
#  'Recccr',
#  'Tinane',
#  'Yuger',
#  'Ua',
#  'Ironheart',
#  'Oake',
#  'Phouled',
#  'Angq',
#  'Spring',
#  'Darks',
#  'Fanco',
#  'Greas',
#  'Heru',
#  'Jelugg',
#  'Krandson',
#  'Lucis',
#  'Zords',
#  'Xecre',
#  'Crescen',
#  'VuOre',
#  'Buged',
#  'Nayles',
#  'Menrins',
#  'Qean',
#  'Wenss',
#  'Ente',
#  'Req',
#  'Timf',
#  'Yer',
#  'Uiget',
#  'In',
#  'Owme',
#  'Pyr',
#  'Almene',
#  'Selle',
#  'Deurica',
#  'Ferle',
#  'Germall',
#  'Hege',
#  'Jean',
#  'Kepper',
#  'Lengi',
#  'Zennous',
#  'Xe',
#  'Cleur',
#  'Veser',
#  'Beart',
#  'Neca',
#  'Mesca',
#  'Qeelle',
#  'Wander',
#  'Edder',
#  'Rninsens',
#  'Travaire',
#  'Ymiges',
#  'Uta',
#  'IMina',
#  'Olviler',
#  'Perral',
#  'Almhnort',
#  'Soeles',
#  'Delvora',
#  'Flies',
#  'Girl',
#  'Hiliaus',
#  'Jrass',
#  'Kelders',
#  'Liges',
#  'Zerna',
#  'X',
#  'Churd',
#  'Vilea',
#  'Barel',
#  'Nerstell',
#  'Mirgon']

# %%
G = list(filter(lambda name: name[0] == "G", place))
G.sort()
G
# Out:
# ['Gabrany',
#  'Gadds',
#  'Gailsor',
#  'Gartuc',
#  'Gehm',
#  'Gels',
#  'Germall',
#  'German',
#  'Giany',
#  'Gind',
#  'Gindsan',
#  'Girl',
#  'Glenna',
#  'Goron',
#  'Graness',
#  'Greas',
#  'Gremon',
#  'Guado',
#  'Guado',
#  'Gurd',
#  'Gurde',
#  'Gurde',
#  'Gurde',
#  'Gurde',
#  'Gurdy',
#  'Gyrls']

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Migita', 'Winds', 'Zeeper', 'Ellen', 'Yeag', 'Vigak', 'Astral',
#        'Dreasen', 'Heird', 'Uller'], dtype='<U12')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Vilea', 'Forest', 'Zwers', 'Minas', 'Nellain', 'Bigts', 'Keeper',
#        'Yunet', 'Nake', 'Xe'], dtype='<U12')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Phamuel', 'Siger', 'Terwal', 'Oiter', 'Elfheim', 'Dyrul', 'Churd',
#        'Pyr', 'Krandson', 'Yarus'], dtype='<U12')

# %%
generate_names()
# Out:
# ['Queen Tteily',
#  'Weator Shake',
#  'Eyel z',
#  'Refora Rosse',
#  'Teth Nodgor',
#  'Yion',
#  'Utothe',
#  'Iverel',
#  'Orvan',
#  'Prometo',
#  'Adray Lellos',
#  'Stony Jeot',
#  'Dagajn',
#  'Fourk Fith',
#  'Gurden',
#  'Harden',
#  'Jage',
#  'Kargo',
#  'Leo',
#  'Zephirin',
#  'Xasher Deangre',
#  'Cinton',
#  'Vavdel',
#  'Blade',
#  'Nagie',
#  'Maurtai']

# %%
model.summary()
# Out:
# Model: "seq_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  20224
# _________________________________________________________________
# gru (GRU)                    multiple                  3938304
# _________________________________________________________________
# gru_1 (GRU)                  multiple                  4133376
# _________________________________________________________________
# dense (Dense)                multiple                  60751
# =================================================================
# Total params: 8,152,655
# Trainable params: 8,152,655
# Non-trainable params: 0
# _________________________________________________________________
