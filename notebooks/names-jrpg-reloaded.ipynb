# %%
import tensorflow as tf
# from tensorflow.keras.layers.experimental import preprocessing

import numpy as np
# import os
import time
# import pickle

# %%
from names import check, raw_data, vectorize, seq_model

# %%
chk = check.CheckPoint("jrpg_model")

# %%
model = chk.load()
model.compile_model()

# %% [markdown]
# ## Generate text

# %% [markdown]
# The simplest way to generate text with this model is to run it in a loop, and keep track of the model's internal state as you execute it.
#
# ![To generate text the model's output is fed back to the input](images/text_generation_sampling.png)
#
# Each time you call the model you pass in some text and an internal state. The model returns a prediction for the next character and its new state. Pass the prediction and state back in to continue generating text.

# %% [markdown]
# The following makes a single step prediction:

# %%
one_step_model = seq_model.OneStep(model)

# %% [markdown]
# Run it in a loop to generate some text. Looking at the generated text, you'll see the model knows when to capitalize, make paragraphs and imitates a Shakespeare-like writing vocabulary. With the small number of training epochs, it has not yet learned to form coherent sentences.

# %%
start = time.time()
result = one_step_model.generate(['Romeo '], 100)
end = time.time()
print(result)
print('\nRun time:', end - start)
# Out:
# ['Romeo S. Kwendi                                                                                           ']
#
# Run time: 2.8697080612182617

# %% [markdown]
# The easiest thing you can do to improve the results is to train it for longer (try `EPOCHS = 30`).
#
# You can also experiment with a different start string, try adding another RNN layer to improve the model's accuracy, or adjust the temperature parameter to generate more or less random predictions.

# %% [markdown]
# If you want the model to generate text *faster* the easiest thing you can do is batch the text generation. In the example below the model generates 5 outputs in about the same time it took to generate 1 above.

# %%
start = time.time()
states = None
result = one_step_model.generate(list("QWERTYUIOPASDFGHJKLZXCVBNM"), 100)
end = time.time()
for line in result:
    print(line.strip())
print('\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# Queen
# Wepta
# Eshel'hald
# Ronyx J.N. S. Beargels
# Tayna'
# Yha Rimo
# Unsah Ameich
# Irula
# O-Ahan-O-ren
# Puffy
# Athereal Queen
# Shaht Deöpu
# Dart
# Fragl
# Gartin
# Holland
# Jennine
# Kupu
# Laddal
# Zek' P Sinna
# Xench
# Captain
# Viliant Vineya
# Buari
# Nobniel
# Master de Forremp
#
#
# ________________________________________________________________________________
#
# Run time: 1.2641818523406982

# %%
def generate_names(stem="", n=1):
    names = []
    for _ in range(n):
        states = None
        next_char = [stem + ch for ch in "QWERTYUIOPASDFGHJKLZXCVBNM"]
        next_char = tf.constant(next_char)
        result = [next_char]

        for n in range(40):
          next_char, states = one_step_model.generate_one_step(next_char, states=states)
          result.append(next_char)

        result = tf.strings.join(result)
        names += [" ".join([a.strip() for a in name.decode("utf-8").split() if len(a)]) for name in result.numpy()]
    return names

# %%
generate_names(n=10)
# Out:
# ['Quina Quen',
#  'Wilrolth',
#  'Exangrup pyrl',
#  'Rena Koy',
#  'Triandra',
#  "Y'mhitra Rucpla",
#  'Uruna',
#  'Igogelika',
#  'Onflyn',
#  'Percia',
#  'Artron',
#  'Spreteney',
#  'Dana',
#  'Flaci',
#  'Gurdor',
#  'Herrand',
#  'Jaa Huxlo',
#  'Kayula',
#  'Lefia',
#  'Zurch',
#  'Xelden of Claus',
#  'Cidoo',
#  'Vickore',
#  'Belling',
#  'Noghoe',
#  'Miki Sauvester',
#  'Quina Quen',
#  'Wirned',
#  'Emhlemettar',
#  'Rademard',
#  'Trealuc',
#  'Yja Ruscle',
#  'Unei',
#  'Igomale',
#  'Orlo',
#  'Palima',
#  'Aahwin',
#  'Spirio',
#  'Dow Nandelle',
#  'Faumet',
#  'Gulool Ja Ja',
#  'Hanter',
#  'Jules',
#  'Kyn',
#  'Lilijht He Burerdins',
#  'Zako Kai',
#  'Xante',
#  'Cenne',
#  'Vearyn',
#  'Bwagi',
#  'Nikien',
#  'Merci',
#  'Quinaze thu Barheau',
#  'Wykkinge Tubllerant',
#  'Eryon',
#  'Rippas',
#  'Tran',
#  'Yairy Lacingag',
#  'Urah',
#  'Isama',
#  'Oaben',
#  'Pulia',
#  'Avarl-darde',
#  'Siby',
#  'Dogohun',
#  'Farleen',
#  'Gurdi',
#  'Hartr',
#  'Jams Danila',
#  'Koby',
#  'Lalloty',
#  'Zever',
#  'Xene',
#  'Clask',
#  'Valsgan Orunir',
#  "B'hy Rhi",
#  'Neney',
#  'Miridel',
#  'Qoqobaan',
#  'Willibhle',
#  'Eleanor',
#  'Rex',
#  'Toreth',
#  'Yasure Rosch',
#  'U Upera',
#  'Ilbard Sith',
#  "O'Ncallia",
#  'Pomm',
#  'Aurvear Que',
#  'Sephiron',
#  'Doa Doblin',
#  'Fludge',
#  'Gentionian',
#  'Hellemant',
#  'Jerof',
#  'Karol Belda',
#  'Lord Lynd',
#  'Zhira',
#  'Xelfira',
#  'Claudia Strife',
#  'Valinz Titta',
#  'Bowmo Teral',
#  'Noog Gah',
#  'Matteys',
#  'Quáen Thett',
#  'Woggera Tenorc',
#  'Ellyn',
#  'Ruber',
#  'Talana Pramathary',
#  'Yen Taimon',
#  'Ulv',
#  'Ignia Ore Timgu',
#  'Owgry',
#  'Puffy',
#  'Amph',
#  'Staric',
#  "D'lhho Tin",
#  'Forlemart',
#  'Gunny',
#  'Hoeling',
#  'Jamiel',
#  'Kae Bahe',
#  'Livard Citbland',
#  'Zeos',
#  'Xishu Seh Bevielle',
#  "Cid's Uhner",
#  'Victor Oakville',
#  "B'nia Tial",
#  'Nonya',
#  'Maria',
#  'Queen of Althel',
#  'Williben',
#  'Eiro',
#  'Reimi Sibi-Ohn Ken',
#  'Toreth',
#  'Yea Risfe',
#  'Utatai',
#  'Isakata Kenders',
#  'Olera Valentine',
#  'Perim',
#  'Arton',
#  'Sikuru',
#  'Doe Evor',
#  'Festari',
#  'Garon',
#  'Hartvell',
#  'Jeee',
#  'Kings of Lichs',
#  'Labuos',
#  'Zehkon',
#  'Xvan',
#  'Chariot Zeol',
#  'Vamia Kisze zol Fentilas',
#  'Blana',
#  'Necron',
#  'Moj',
#  'Quan',
#  'Wittcov',
#  'Emevansel Fleecho?',
#  'Rygeia Owiny',
#  'TraAleron',
#  'Yukotku',
#  'Ukara-Sorh',
#  "I'laribe",
#  'Oora',
#  'Perima',
#  'Akusui',
#  'Stephan',
#  'Daverlan',
#  'Fardie',
#  "G'reani",
#  'Horisun',
#  'Jenoma',
#  'Klai Koya',
#  'Luca',
#  'Zye Helbhon',
#  "X'lkun",
#  'Claud Ourd',
#  'Vulkor',
#  'Belzen',
#  'Nottri',
#  'Master Craftm',
#  'Quino',
#  'Willerm Br Alleny Ore Aldercapt',
#  'Edgram',
#  "Rika'llof Tiller",
#  'Tasaco',
#  'Yau-Ohna',
#  'Urich',
#  'Iruna',
#  'Oronche',
#  'Portine',
#  'Azale',
#  'Sai-Leeq',
#  'Denneth Walfan',
#  'Fiorel',
#  'Ginkle',
#  'Harts',
#  'Janard',
#  'Kumo',
#  'Lasso',
#  'Zephyn',
#  'Xelph',
#  'Carburion',
#  'Vaegoh',
#  'Barmetor',
#  'Nailahne',
#  'Mobria Carnoc',
#  'Quince',
#  'Welch Vineyard',
#  'Enna',
#  'Refeaule',
#  'Twump',
#  'Yekor VIIghty',
#  'Urdi',
#  'Inse-Farpine',
#  'Oekbert',
#  'Puir',
#  'Albinaul wolds',
#  'Silvairler',
#  'Dr. Keddems',
#  'Felo',
#  'Gilgamesh',
#  'Horgen',
#  'Jannequinand',
#  'Karpia',
#  'Leehog',
#  'Zingomm',
#  'Xake Demuzi',
#  'Creuju',
#  'Vecboro',
#  'Belch Vineyard',
#  'Nerrich',
#  'Mogras of Liansco',
#  'Que Rain',
#  'Wastan',
#  'Elena',
#  'Reikin',
#  'Tyra',
#  "Yaz'laPa",
#  'Uram',
#  'Ignasse',
#  'Opcicc',
#  'Peiric',
#  'Adelle',
#  'Sephirot',
#  'Darcian',
#  'Flarrle',
#  "G'neani",
#  "H'thabiv",
#  'Janrele',
#  'Ka',
#  'Lefe',
#  'Zebo',
#  'Xelphel Waliss',
#  'Cold',
#  'Viltama',
#  'Belle Shantotto',
#  'Noel Resser',
#  'Mavilis']

# %%
generate_names('Joby of ', n=10)
# Out:
# ['Joby of Queen of',
#  'Joby of Wist',
#  'Joby of Estie',
#  'Joby of Rels',
#  'Joby of Triepepe',
#  'Joby of Yen lov',
#  'Joby of Urgent',
#  'Joby of Ieski',
#  'Joby of Obina',
#  'Joby of Pileze',
#  'Joby of Abla',
#  'Joby of Selle',
#  'Joby of Delent',
#  'Joby of Forten',
#  'Joby of Gindson',
#  'Joby of Hinde',
#  'Joby of Juris',
#  'Joby of Kelde',
#  'Joby of Liggs',
#  'Joby of Zeep',
#  'Joby of X Moug',
#  'Joby of Chefoge',
#  'Joby of Velltingair',
#  'Joby of Bobon',
#  'Joby of Ne Hoisen',
#  'Joby of Meru',
#  'Joby of Queen',
#  'Joby of Welds',
#  'Joby of Eblino',
#  'Joby of Risunt',
#  'Joby of Tibllers',
#  'Joby of Yeeq',
#  'Joby of Uncevole',
#  'Joby of I',
#  'Joby of Obina',
#  'Joby of Pilntrinsy',
#  'Joby of Akenton',
#  'Joby of Shai',
#  'Joby of Deldon',
#  'Joby of Fore',
#  'Joby of Gulds',
#  'Joby of Heiry',
#  'Joby of Jews',
#  'Joby of Kelqie',
#  'Joby of Limk',
#  'Joby of Zelvor',
#  'Joby of X Queen',
#  'Joby of Couner',
#  'Joby of Velly',
#  'Joby of Blind',
#  'Joby of Nelo',
#  'Joby of Mession',
#  'Joby of Queen',
#  'Joby of Weld',
#  'Joby of Epire',
#  'Joby of Rous ineq',
#  'Joby of Teller',
#  'Joby of Yes Lome',
#  'Joby of Uperna',
#  'Joby of Ies',
#  'Joby of Ovici',
#  'Joby of Peller',
#  'Joby of Agentior',
#  'Joby of Shieds',
#  'Joby of Dantor',
#  'Joby of Fair',
#  'Joby of Gurde',
#  'Joby of Hunder',
#  'Joby of Jibes',
#  'Joby of Kelders',
#  'Joby of Liggs',
#  'Joby of Zebe',
#  'Joby of Xon',
#  'Joby of Chrisson e',
#  'Joby of Van',
#  'Joby of Bebbr',
#  'Joby of Nebera',
#  'Joby of Midus',
#  'Joby of Quen',
#  'Joby of Wurel',
#  'Joby of Ezeer',
#  'Joby of Reet',
#  'Joby of Teller',
#  'Joby of Yee',
#  'Joby of U Trowe',
#  'Joby of Inceens',
#  'Joby of Oben',
#  'Joby of Porne',
#  'Joby of Asbuna',
#  'Joby of Seller',
#  'Joby of Deeq',
#  'Joby of Fyrel',
#  'Joby of Ginds',
#  'Joby of Hibdle',
#  'Joby of Junners',
#  'Joby of Kenny',
#  'Joby of Liggs',
#  'Joby of Zeido',
#  'Joby of Xpet Feird',
#  'Joby of Cornelia',
#  'Joby of Ville',
#  'Joby of Bebb',
#  'Joby of Nelis',
#  'Joby of Milda',
#  'Joby of Queel',
#  'Joby of Wanterw',
#  'Joby of Edferioge',
#  'Joby of Ree',
#  'Joby of Tilmeress',
#  'Joby of Yee',
#  'Joby of Uuler',
#  'Joby of Ice',
#  'Joby of Obr',
#  'Joby of Peller',
#  'Joby of Asthell',
#  'Joby of Solle',
#  'Joby of Dees',
#  'Joby of Forrel',
#  'Joby of Green',
#  'Joby of Hindello',
#  'Joby of June',
#  'Joby of Keds',
#  'Joby of Lionst',
#  'Joby of Zuedo',
#  'Joby of XI',
#  'Joby of Cornelia',
#  'Joby of Vineyard',
#  'Joby of Bebed',
#  'Joby of Nun s Forge',
#  'Joby of Mello',
#  'Joby of Queen of Vestue',
#  'Joby of Windsus',
#  'Joby of Eile',
#  'Joby of Relour',
#  'Joby of Toblen',
#  'Joby of Yen Mourtain',
#  'Joby of Underolle',
#  'Joby of Iveilo',
#  'Joby of Ovies',
#  'Joby of Phildengre',
#  'Joby of Avi a',
#  'Joby of Sesse',
#  'Joby of Delverta',
#  'Joby of Firter',
#  'Joby of Gigss',
#  'Joby of Highwind',
#  'Joby of Jeen',
#  'Joby of Krise',
#  'Joby of Linds',
#  'Joby of Zeewor',
#  'Joby of Xe',
#  'Joby of Connd Courd',
#  'Joby of Verstines',
#  'Joby of Blund Fobyl',
#  'Joby of Nelkior',
#  'Joby of Miller',
#  'Joby of Queen',
#  'Joby of Wind',
#  'Joby of Elqie',
#  'Joby of Rele',
#  'Joby of Tlisous Fore',
#  'Joby of Youg chiel',
#  'Joby of Ute',
#  'Joby of Iesne',
#  'Joby of Ooby',
#  'Joby of Pille',
#  'Joby of Aulmore',
#  'Joby of Sulvertal',
#  'Joby of Delle',
#  'Joby of Fineldors',
#  'Joby of Guyde',
#  'Joby of Highwind',
#  'Joby of Jeous',
#  'Joby of Kee',
#  'Joby of Lector',
#  'Joby of Zelders',
#  'Joby of Xeq',
#  'Joby of Celesta',
#  'Joby of Vigian',
#  'Joby of Brosos',
#  'Joby of Nelle',
#  'Joby of Migeg',
#  'Joby of Qeenno',
#  'Joby of Wentz',
#  'Joby of Elmed',
#  'Joby of Rescel',
#  'Joby of Tel',
#  'Joby of Yanzer',
#  'Joby of Uthi',
#  'Joby of Iepe',
#  'Joby of Oelve',
#  'Joby of Pellor',
#  'Joby of Arben',
#  'Joby of Sibllyrs XV Ake',
#  'Joby of Dorgen',
#  'Joby of Fomteepep',
#  'Joby of Genst',
#  'Joby of Hinde',
#  'Joby of Julse',
#  'Joby of Kborov',
#  'Joby of Lince',
#  'Joby of Zelds',
#  'Joby of Xle vins',
#  'Joby of Cornelie',
#  'Joby of Vigel Oesse',
#  'Joby of Bros',
#  'Joby of Nelle',
#  'Joby of Miggle',
#  'Joby of Queen',
#  'Joby of Well',
#  'Joby of Ebrna',
#  'Joby of Rhoile',
#  'Joby of Thiemon',
#  'Joby of Yee',
#  'Joby of Uldilor',
#  'Joby of Idoriber',
#  'Joby of Obyna',
#  'Joby of Peller',
#  'Joby of Ablan',
#  'Joby of Sis qeon',
#  'Joby of Debud',
#  'Joby of Firle',
#  'Joby of Geruuge',
#  'Joby of Hugdee',
#  'Joby of Jeruin',
#  'Joby of Keinus',
#  'Joby of Link',
#  'Joby of Zelder',
#  'Joby of Xise',
#  'Joby of Cornelia',
#  'Joby of Villiers',
#  'Joby of Beird',
#  'Joby of Nelvielle',
#  'Joby of Melve',
#  'Joby of Quen',
#  'Joby of Wigns',
#  'Joby of Elder',
#  'Joby of Rev Four',
#  'Joby of Teeld',
#  'Joby of Yogster',
#  'Joby of Uilveress',
#  'Joby of Iceegor',
#  'Joby of Old Mande',
#  'Joby of Piller',
#  'Joby of Abielpe',
#  'Joby of Silvelletk',
#  'Joby of Deescel',
#  'Joby of Fietys',
#  'Joby of Gindwess',
#  'Joby of Hinde',
#  'Joby of Jessue',
#  'Joby of Keper',
#  'Joby of Lint',
#  'Joby of Zeemost',
#  'Joby of Xeg',
#  'Joby of Corneli',
#  'Joby of Vouue',
#  'Joby of Biddgiold',
#  'Joby of Nelver',
#  'Joby of Melu']

# %%
generate_names('Joby the ')
# Out:
# ['Joby the Qeone',
#  'Joby the Wunter',
#  'Joby the Ezendisen',
#  'Joby the Reeper',
#  'Joby the Touribel',
#  'Joby the Yougoha',
#  'Joby the Ulonher',
#  'Joby the Iesitt',
#  'Joby the Oviof',
#  'Joby the Powliges',
#  'Joby the Alo andoror',
#  'Joby the Seledeire',
#  'Joby the Deepblly',
#  'Joby the Forresure',
#  'Joby the Goron',
#  'Joby the How',
#  'Joby the Juna',
#  'Joby the Kou saine',
#  'Joby the Loibend',
#  'Joby the Zeepe',
#  'Joby the X Uncenos',
#  'Joby the Corwoni',
#  'Joby the Vessione',
#  'Joby the Beonbe',
#  'Joby the Nawibo',
#  'Joby the Mountain']

# %%
place = []
for name in generate_names():
    name = name.split()[0]
    for long_name in generate_names(name + " of "):
        print(long_name)
        place.append(long_name.split()[2])
# Out:
# Quina of Quent
# Quina of Wint
# Quina of Elthe
# Quina of Randss
# Quina of Trean
# Valleraud of Cimngisinpen
# Valleraud of Vestitah
# Valleraud of Brosanso
# Valleraud of Nerrince
# Valleraud of Mander
# Berrit of Queen
# Berrit of Warden
# Berrit of Eldensiper
# Berrit of Ren
# Berrit of Tionss
# Berrit of Ynskers
# Berrit of Upetarra
# Berrit of Is
# Berrit of Oyello
# Berrit of Pilla
# Berrit of Astral
# Berrit of Scyone
# Berrit of Duriness ter
# Berrit of Funtemin
# Berrit of Gyrls
# Berrit of Hindy
# Berrit of Jeance
# Berrit of Kirdson
# Berrit of Luncess
# Berrit of Zondos
# Berrit of Xndicusia
# Berrit of Chiur
# Berrit of Vynerco
# Berrit of Byrde
# Berrit of Nonsersep
# Berrit of Mountain
# Naxzre of Quyne
# Naxzre of Wyrde
# Naxzre of Elmen
# Naxzre of Rufe
# Naxzre of Track Farrense
# Naxzre of Yarusa
# Naxzre of Urvan
# Naxzre of Innequin Traid
# Naxzre of Ovi
# Naxzre of Prase
# Naxzre of Auth
# Naxzre of Salen
# Naxzre of Daro
# Naxzre of Farree
# Naxzre of Grandson
# Naxzre of Highwand
# Naxzre of Jeanic
# Naxzre of Kant re Forrest Sol Be
# Naxzre of Lage
# Naxzre of Zewenq
# Naxzre of Xalkker
# Naxzre of Creation
# Naxzre of Vara
# Naxzre of Blindsat Hanety
# Naxzre of Nate
# Naxzre of Myrle of Man
# Medriaus of Queen
# Medriaus of Welms
# Medriaus of Emmel
# Medriaus of Rev
# Medriaus of Tes Lek
# Medriaus of Yes
# Medriaus of Uddr
# Medriaus of Iruseeren
# Medriaus of Oure
# Medriaus of Pellan
# Medriaus of Aulmour Omemes
# Medriaus of Scel
# Medriaus of Derrd
# Medriaus of Fisters
# Medriaus of Grants
# Medriaus of Henes
# Medriaus of Jess
# Medriaus of Kelle
# Medriaus of Leyn
# Medriaus of Zeller
# Medriaus of Xe Belle
# Medriaus of Creepi
# Medriaus of Venstige
# Medriaus of Burt
# Medriaus of Nelrer
# Medriaus of Mirage

# %%
place
# Out:
# ['Quent',
#  'Wint',
#  'Elthe',
#  'Randss',
#  'Trean',
#  'Yel',
#  'Ullena',
#  'Itters',
#  'Obrir',
#  'Parten',
#  'Anten',
#  'Stre',
#  'Darns',
#  'Fant',
#  'Grant',
#  'Heart',
#  'Jurit',
#  'Kirle',
#  'Lent',
#  'Zeep',
#  'XWes',
#  'Cardles',
#  'Vani',
#  'Blend',
#  'Naure',
#  'Man',
#  'Qus',
#  'Wall',
#  'Elfhene',
#  'Ratelson',
#  'Tanter',
#  'Ya',
#  'Ungetron',
#  'I',
#  'Obenord',
#  'Powella',
#  'Abenner',
#  'Snage',
#  'Dart',
#  'Fance',
#  'Gablon',
#  'Hyrus',
#  'Jackka',
#  'Kards',
#  'Linke',
#  'Zanty',
#  'X',
#  'Cornelia',
#  'Van',
#  'Barden',
#  'Naza',
#  'Marice',
#  'Queen',
#  'Wallus',
#  'Eake',
#  'Rell',
#  'Tarden',
#  'Yer',
#  'Utteer',
#  'Izules',
#  'Olk',
#  'Pav',
#  'Allan',
#  'Simer',
#  'Darken',
#  'Fleanios',
#  'Guntw',
#  'Harvi',
#  'Jess',
#  'Kelvor',
#  'Lima',
#  'Zarvs',
#  'Xan',
#  'Clabe',
#  'Vellura',
#  'Bor',
#  'Nage',
#  'Murtai',
#  'Quen',
#  'Welsce',
#  'Euter',
#  'Rissen',
#  'Thiaf',
#  'Yond',
#  'Unille',
#  'Itella',
#  'Oor',
#  'Pinter',
#  'Albendon',
#  'Screv',
#  'Dragess',
#  'Forleneus',
#  'Granss',
#  'Hunter',
#  'Junt',
#  'Kiine',
#  'Lent',
#  'Znake',
#  'Xon',
#  'Cardus',
#  'Van',
#  'Borte',
#  'Nugkle',
#  'Manter',
#  'Qeol',
#  'Wind',
#  'Elfhenmain',
#  'Rick',
#  'Tire',
#  'Yelqus',
#  'Ucker',
#  'Intoge',
#  'Ordin',
#  'Prina',
#  'Alf5i',
#  'Sages',
#  'Dria',
#  'Frac',
#  'Gurde',
#  'Hinders',
#  'Jama',
#  'Kant',
#  'Link',
#  'Zingoh',
#  'X',
#  'Chier',
#  'Villa',
#  'Brindo',
#  'Norge',
#  'Me',
#  'Queen',
#  'Wylde',
#  'Ellen',
#  'Raven',
#  'Tiomas',
#  'Yanv',
#  'Unner',
#  'Ikuna',
#  'O-Lunnar',
#  'Pyrna',
#  'Astral',
#  'Scregton',
#  'Dangus',
#  'Firal',
#  'Guard',
#  'Higher',
#  'Jugal',
#  'Knnings',
#  'Light',
#  'Zelda',
#  'XX',
#  'Carnus',
#  'Vinalac',
#  'Barvele',
#  'Nerch',
#  'Manice',
#  'Que',
#  'Wirmer',
#  'Eblin',
#  'Ranaflen',
#  'Tionts',
#  'Yaint',
#  'Uldore',
#  'Istrai',
#  'Obrir',
#  'Pimewal',
#  'Astral',
#  'Sailes',
#  'Doupece',
#  'Fobltein',
#  'Grandason',
#  'Hargus',
#  'Jarve',
#  'Kiand',
#  'Leance',
#  'Zeine',
#  'XIII',
#  'Carrus',
#  'Vari',
#  'Barents',
#  'Nacu',
#  'Mari',
#  'Qulen',
#  'Wlane',
#  'Evizezee',
#  'Remon',
#  'Troder',
#  'Yesle',
#  'Uller',
#  'Icea',
#  'Older',
#  'Pille',
#  'Astral',
#  'Seller',
#  'Danvolle',
#  'Fornes',
#  'Gess',
#  'Heidan',
#  'June',
#  'Keller',
#  'Lachericc',
#  'Zelvall',
#  'X-Aren',
#  'Cornelia',
#  'Veider',
#  'Barves',
#  'Never',
#  'Mighwind',
#  'Queen',
#  'Waltz',
#  'Eurcen',
#  'Rors',
#  'Than',
#  'Yveci',
#  'Ullen',
#  'Iaville',
#  'Osire',
#  'Perral',
#  'Aurcint',
#  'Screge',
#  'Dalduse',
#  'Furres',
#  'Gurle',
#  'Hyllerssin',
#  'Jullemald',
#  'Kpev',
#  'Lucis',
#  'Zhiva',
#  'X',
#  'Cornelia',
#  'Van',
#  'Beard',
#  'Nevicca',
#  'Mugher',
#  'Quen',
#  'Wyrd',
#  'Ellel',
#  'Restor',
#  'Therdalesus',
#  'Yeste',
#  'Uulem',
#  'Iluna',
#  'Ostiel',
#  'Pwordsons',
#  'Auttrem',
#  'Stell',
#  'Dloustss',
#  'Fleure',
#  'Guard',
#  'Hegrin',
#  'Juggler',
#  'Kirgs',
#  'Lansfeld',
#  'Zardo',
#  'Xf',
#  'Cornelia',
#  'Vemes',
#  'Barent',
#  'Nugler',
#  'Mello',
#  'Qeel',
#  'W.fta',
#  'Evena',
#  'Riea',
#  'Tiane',
#  'Yeri',
#  'Uperra',
#  'Irami',
#  'Oen',
#  'Parmani',
#  'Adiaa',
#  'Simar',
#  'Darken',
#  'Farges',
#  'Glennas',
#  'Heira',
#  'Jequl',
#  'Khurio',
#  'Link',
#  'Zernor',
#  'Xen',
#  'Civer',
#  'Vitaha',
#  'Barvon',
#  "Nei'ka",
#  'Mark',
#  'Qeenos',
#  'Wind',
#  'Elmi',
#  'Reus',
#  'Teller',
#  'Yamuk',
#  'Ullin',
#  'Inogh',
#  'Obo',
#  'Piller',
#  'Albel',
#  'Suller',
#  'Dyelus',
#  'Fleure',
#  'Gron',
#  'Hyrule',
#  'Josta',
#  'Kens',
#  'Lind',
#  'Zelle',
#  'Xis',
#  'Clifp',
#  'Vistaul',
#  'Balvo',
#  "Nigg's",
#  'Mack',
#  'Qeol',
#  'Wyrls',
#  'Emara',
#  'Rysce',
#  'Tradas',
#  'Ye',
#  'Uccer',
#  'In',
#  'Omny',
#  'Phlie',
#  'Aller',
#  'Swand',
#  'Delle',
#  'Fiblon',
#  'Geys',
#  'Herker',
#  'JeaP',
#  'Kwaga',
#  'Led',
#  'Zeep',
#  'X',
#  'Child',
#  'Velant',
#  'Beq',
#  'Nera',
#  'Magi',
#  'Qharl',
#  'Warres',
#  'Ellen',
#  'Rines',
#  'Timas',
#  'Yarak',
#  'Untelle',
#  'Insi',
#  'Okent',
#  'Parenes',
#  'Allan',
#  'Sagen',
#  'Darmes',
#  'Fitis',
#  'Gians',
#  'Harke',
#  'Janssel',
#  'Kerds',
#  'Landss',
#  'Zards',
#  'Xons',
#  'Cinan',
#  'Vagder',
#  'Barte',
#  'Nervall',
#  'Man',
#  'Qhow',
#  'Wrath',
#  'Ebnanshor',
#  'Romer',
#  'Trina',
#  'Yenvorg',
#  'Uncelo',
#  'Ince',
#  'Omntrep',
#  'Prine',
#  'Angoro',
#  'Sprieps',
#  'Dengor',
#  'Flole',
#  'Grand',
#  'Higwwer',
#  'Jugglers',
#  'Kinberst',
#  'Light',
#  'Zerg',
#  'Xe8',
#  'Chore',
#  'Vugem',
#  'Broshers',
#  'Niggre',
#  'Mir',
#  'Queen',
#  'Wyrdles',
#  'Elfheim',
#  'Recopt',
#  'Turmer',
#  'Yorgs',
#  'Ullenish',
#  'Ivon',
#  'Ovenige',
#  'Piltan',
#  'Aulmmin',
#  'Seller',
#  'Delva',
#  'Furres',
#  'Girva',
#  'Helos',
#  'Jucis',
#  'Kinnersm',
#  'Lugan',
#  'Zelders',
#  'X',
#  'Curnssant',
#  'Vevinage',
#  'Blversan',
#  'Nuire',
#  'Murveric',
#  'Quen',
#  'Wyrm',
#  'Ekle',
#  'Relders',
#  'Tine',
#  'Yennit',
#  'Uzeilla',
#  'Intitus',
#  'Oile',
#  'Pyrs',
#  'Aprent',
#  'Snaldor',
#  'Dorpena',
#  'Forest',
#  'Girla',
#  'Herdo',
#  'Julisost',
#  'Kirner',
#  'Leance',
#  'Zelder',
#  'Xep',
#  'Chire',
#  'Veilal',
#  'Brosse',
#  'Nervall',
#  'Merica',
#  'Qeol',
#  'Winds',
#  'Eblen',
#  'Ravns',
#  'Tin',
#  'Yelq',
#  'Upreela',
#  'Ingigor',
#  'Oken',
#  'Pot',
#  'Adi',
#  'Siple',
#  'Delva',
#  'Fimin',
#  'Garlon',
#  'Hiah',
#  'Julk',
#  'Kind',
#  'Lighth',
#  'Zeld',
#  'X',
#  'Cinys',
#  'Villiet',
#  'Bys',
#  'Nabu',
#  'Mae',
#  'Qeeper',
#  'Withowle',
#  'Elfmeim',
#  'Ringer',
#  'Tiller',
#  'Yes',
#  'Undrol',
#  'Ivelle',
#  'Olfer',
#  'Parvess',
#  'Alder',
#  'Seller',
#  'Dincess',
#  'Fyrgs',
#  'Gindwust',
#  'Hindlers',
#  'Jigle',
#  'Kee',
#  'Luge',
#  'Zemes',
#  'Xen',
#  'Corneli',
#  'Velter',
#  'Byrde',
#  'Nustulle',
#  'Mild',
#  'Qeen',
#  'Winds',
#  'Eggh',
#  'Rel',
#  'Tirle',
#  'Yepar',
#  'Unce',
#  'Iviney',
#  'Oves',
#  'Prince',
#  'Astral',
#  'Shief',
#  'Dinage',
#  'Fyng',
#  'Griver',
#  'Henti',
#  'Jenk',
#  'Kenfyr',
#  'Link',
#  'Zelda',
#  'Xele',
#  'Chris',
#  'Vindeur',
#  'Be',
#  'Neku',
#  'Munt',
#  'Qoen',
#  'Wlate',
#  'Edero',
#  'Ryser',
#  'Tland',
#  'Yeld',
#  'Unle',
#  'Ii',
#  'Older',
#  'Phalusto',
#  'Allen',
#  'Steepin',
#  'Deild',
#  'Fleure',
#  'Girtweltin',
#  'Hent',
#  'Jeanson',
#  'Kill',
#  'Lemuin',
#  'Zind',
#  'XI',
#  'Cintleos',
#  'Vaveric',
#  'Burmet',
#  'Nanders',
#  'Miresan',
#  'Qeen',
#  'Wlate',
#  'Ellen',
#  'Rel',
#  'Tistal',
#  'Ynvica',
#  'Uperpa',
#  'Itters',
#  'Orna',
#  'Prascens',
#  'Allen',
#  'Simler',
#  'Dornes',
#  'Flan',
#  'Glaus',
#  'Hermar',
#  'Jeana',
#  'Kings',
#  'Livi',
#  'Zeleger',
#  'Xncaon',
#  'Cloud',
#  'Veller',
#  'Bramper',
#  'Neruja',
#  'Minas',
#  'Quen',
#  'Windgers',
#  'Elfem',
#  'Roverson',
#  'Toron',
#  'Yrosess',
#  'Urldnars',
#  'Intiless',
#  'Oulmere',
#  'Purtesmane',
#  'Azelira',
#  'Silvagert',
#  'Digesser',
#  'Fittir',
#  'Gronson',
#  'Hurter',
#  'Jink',
#  'Kriss',
#  'Links',
#  'Zelde',
#  'XII',
#  'Cimngisinpen',
#  'Vestitah',
#  'Brosanso',
#  'Nerrince',
#  'Mander',
#  'Queen',
#  'Warden',
#  'Eldensiper',
#  'Ren',
#  'Tionss',
#  'Ynskers',
#  'Upetarra',
#  'Is',
#  'Oyello',
#  'Pilla',
#  'Astral',
#  'Scyone',
#  'Duriness',
#  'Funtemin',
#  'Gyrls',
#  'Hindy',
#  'Jeance',
#  'Kirdson',
#  'Luncess',
#  'Zondos',
#  'Xndicusia',
#  'Chiur',
#  'Vynerco',
#  'Byrde',
#  'Nonsersep',
#  'Mountain',
#  'Quyne',
#  'Wyrde',
#  'Elmen',
#  'Rufe',
#  'Track',
#  'Yarusa',
#  'Urvan',
#  'Innequin',
#  'Ovi',
#  'Prase',
#  'Auth',
#  'Salen',
#  'Daro',
#  'Farree',
#  'Grandson',
#  'Highwand',
#  'Jeanic',
#  'Kant',
#  'Lage',
#  'Zewenq',
#  'Xalkker',
#  'Creation',
#  'Vara',
#  'Blindsat',
#  'Nate',
#  'Myrle',
#  'Queen',
#  'Welms',
#  'Emmel',
#  'Rev',
#  'Tes',
#  'Yes',
#  'Uddr',
#  'Iruseeren',
#  'Oure',
#  'Pellan',
#  'Aulmour',
#  'Scel',
#  'Derrd',
#  'Fisters',
#  'Grants',
#  'Henes',
#  'Jess',
#  'Kelle',
#  'Leyn',
#  'Zeller',
#  'Xe',
#  'Creepi',
#  'Venstige',
#  'Burt',
#  'Nelrer',
#  'Mirage']

# %%
G = list(filter(lambda name: name[0] == "G", place))
G.sort()
G
# Out:
# ['Gablon',
#  'Garlon',
#  'Gess',
#  'Geys',
#  'Gians',
#  'Gindwust',
#  'Girla',
#  'Girtweltin',
#  'Girva',
#  'Glaus',
#  'Glennas',
#  'Grand',
#  'Grandason',
#  'Grandson',
#  'Granss',
#  'Grant',
#  'Grants',
#  'Griver',
#  'Gron',
#  'Gronson',
#  'Guard',
#  'Guard',
#  'Guntw',
#  'Gurde',
#  'Gurle',
#  'Gyrls']

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Insi', 'Julk', 'Piller', 'Fisters', 'Qeol', 'Yes', 'Aulmour',
#        'Zondos', 'Elfem', 'Remon'], dtype='<U12')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Euter', 'Venstige', 'Seller', 'Blend', 'Carnus', 'Chire', 'Ryser',
#        'Ratelson', 'Unner', 'Romer'], dtype='<U12')

# %%
np.random.choice(place, size=10, replace=False)
# Out:
# array(['Seller', 'Vynerco', 'Reus', 'Quen', 'Istrai', 'Beard', 'Astral',
#        'Vitaha', 'Prascens', 'Tionts'], dtype='<U12')

# %%
generate_names()
# Out:
# ['Quena',
#  'Wagen',
#  'Elussimeci',
#  'Ran farrina',
#  'Torkzus',
#  'Yoyayrus',
#  'Un',
#  'Ignaverick',
#  'Oleva',
#  'Pairdin',
#  'Auraine Aunorminc Ore',
#  'Savta',
#  'Doron',
#  'Fasle',
#  'Gorzanger',
#  'Hurdy',
#  'Jantle',
#  'Kithah Delper',
#  'Lasha',
#  'Zaego',
#  'Xevig Silsherty',
#  'Claug Last',
#  'Veeller',
#  'Barisea',
#  'Nelly',
#  'Maricelle']

# %%
model.summary()
# Out:
# Model: "seq_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  20224
# _________________________________________________________________
# gru (GRU)                    multiple                  3938304
# _________________________________________________________________
# gru_1 (GRU)                  multiple                  4133376
# _________________________________________________________________
# dense (Dense)                multiple                  60751
# =================================================================
# Total params: 8,152,655
# Trainable params: 8,152,655
# Non-trainable params: 0
# _________________________________________________________________
